# %% [markdown]
# ## Overview
#
# This notebook will show you how to create and query a table or DataFrame that you uploaded to DBFS. [DBFS](https://docs.databricks.com/user-guide/dbfs-databricks-file-system.html) is a Databricks File System that allows you to store data for querying inside of Databricks. This notebook assumes that you have a file already inside of DBFS that you would like to read from.
#
# This notebook is written in **Python** so the default cell type is Python. However, you can use different languages by using the `%LANGUAGE` syntax. Python, Scala, SQL, and R are all supported.

# %%
import glob
import os 
import pandas as pd
from pyspark.sql.functions import split
import re
import numpy as np
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# File location and type
file_location = "/FileStore/tables/NASA_access_log_Jul95-1.gz"
my_list = []
# The applied options are for CSV files. For other file types, these will be ignored.
df = spark.read.csv(file_location, sep=' ')
#df = df.select(split(df._c5, ' ').alias(['type','a1','a2'])).collect()
my_list = df.select('_c5').rdd.flatMap(lambda x: x).collect()
my_list2 = df.select('_c0').rdd.flatMap(lambda x: x).collect()
my_list3 = df.select('_c7').rdd.flatMap(lambda x: x).collect()
my_list4 = df.select('_c3').rdd.flatMap(lambda x: x).collect()
my_list5 = df.select('_c4').rdd.flatMap(lambda x: x).collect()
my_list6 = df.select('_c6').rdd.flatMap(lambda x: x).collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(df.tail(1000))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>_c0</th><th>_c1</th><th>_c2</th><th>_c3</th><th>_c4</th><th>_c5</th><th>_c6</th><th>_c7</th></tr></thead><tbody><tr><td>esdmac166.arlut.utexas.edu</td><td>-</td><td>-</td><td>[28/Jul/1995:13:16:12</td><td>-0400]</td><td>GET /icons/menu.xbm HTTP/1.0</td><td>200</td><td>527</td></tr><tr><td>esdmac166.arlut.utexas.edu</td><td>-</td><td>-</td><td>[28/Jul/1995:13:16:12</td><td>-0400]</td><td>GET /icons/image.xbm HTTP/1.0</td><td>200</td><td>509</td></tr><tr><td>esdmac166.arlut.utexas.edu</td><td>-</td><td>-</td><td>[28/Jul/1995:13:16:13</td><td>-0400]</td><td>GET /icons/blank.xbm HTTP/1.0</td><td>200</td><td>509</td></tr><tr><td>131.182.170.137</td><td>-</td><td>-</td><td>[28/Jul/1995:13:16:16</td><td>-0400]</td><td>GET /images/ksclogo-medium.gif HTTP/1.0</td><td>200</td><td>5866</td></tr><tr><td>128.203.26.245</td><td>-</td><td>-</td><td>[28/Jul/1995:13:16:20</td><td>-0400]</td><td>GET /software/winvn/winvn.html HTTP/1.0</td><td>200</td><td>9866</td></tr><tr><td>198.240.108.240</td><td>-</td><td>-</td><td>[28/Jul/1995:13:16:21</td><td>-0400]</td><td>GET /images/ HTTP/1.0</td><td>200</td><td>17688</td></tr><tr><td>128.203.26.245</td><td>-</td><td>-</td><td>[28/Jul/1995:13:16:21</td><td>-0400]</td><td>GET /software/winvn/winvn.gif HTTP/1.0</td><td>304</td><td>0</td></tr><tr><td>128.203.26.245</td><td>-</td><td>-</td><td>[28/Jul/1995:13:16:21</td><td>-0400]</td><td>GET /images/construct.gif HTTP/1.0</td><td>304</td><td>0</td></tr><tr><td>128.203.26.245</td><td>-</td><td>-</td><td>[28/Jul/1995:13:16:21</td><td>-0400]</td><td>GET /software/winvn/bluemarb.gif HTTP/1.0</td><td>304</td><td>0</td></tr><tr><td>128.203.26.245</td><td>-</td><td>-</td><td>[28/Jul/1995:13:16:21</td><td>-0400]</td><td>GET /software/winvn/wvsmall.gif HTTP/1.0</td><td>304</td><td>0</td></tr><tr><td>esdmac166.arlut.utexas.edu</td><td>-</td><td>-</td><td>[28/Jul/1995:13:16:22</td><td>-0400]</td><td>GET /history/apollo/apollo-13/ HTTP/1.0</td><td>200</td><td>1732</td></tr><tr><td>esdmac166.arlut.utexas.edu</td><td>-</td><td>-</td><td>[28/Jul/1995:13:16:23</td><td>-0400]</td><td>GET /icons/text.xbm HTTP/1.0</td><td>200</td><td>527</td></tr><tr><td>131.182.170.137</td><td>-</td><td>-</td><td>[28/Jul/1995:13:16:25</td><td>-0400]</td><td>GET /images/NASA-logosmall.gif HTTP/1.0</td><td>200</td><td>786</td></tr><tr><td>128.203.26.245</td><td>-</td><td>-</td><td>[28/Jul/1995:13:16:25</td><td>-0400]</td><td>GET /images/KSC-logosmall.gif HTTP/1.0</td><td>304</td><td>0</td></tr><tr><td>128.203.26.245</td><td>-</td><td>-</td><td>[28/Jul/1995:13:16:25</td><td>-0400]</td><td>GET /images/MOSAIC-logosmall.gif HTTP/1.0</td><td>304</td><td>0</td></tr><tr><td>128.203.26.245</td><td>-</td><td>-</td><td>[28/Jul/1995:13:16:25</td><td>-0400]</td><td>GET /images/USA-logosmall.gif HTTP/1.0</td><td>304</td><td>0</td></tr><tr><td>128.203.26.245</td><td>-</td><td>-</td><td>[28/Jul/1995:13:16:25</td><td>-0400]</td><td>GET /images/WORLD-logosmall.gif HTTP/1.0</td><td>304</td><td>0</td></tr><tr><td>piweba1y.prodigy.com</td><td>-</td><td>-</td><td>[28/Jul/1995:13:16:25</td><td>-0400]</td><td>GET /history/mercury/flight-summary.txt HTTP/1.0</td><td>200</td><td>959</td></tr><tr><td>s14.vie1.austria.eu.net</td><td>-</td><td>-</td><td>[28/Jul/1995:13:16:26</td><td>-0400]</td><td>GET /shuttle/technology/sts-newsref/et.html HTTP/1.0</td><td>200</td><td>20327</td></tr><tr><td>star1.stsci.edu</td><td>-</td><td>-</td><td>[28/Jul/1995:13:16:26</td><td>-0400]</td><td>GET /history/astp/astp.html HTTP/1.0</td><td>200</td><td>1157</td></tr><tr><td>star1.stsci.edu</td><td>-</td><td>-</td><td>[28/Jul/1995:13:16:26</td><td>-0400]</td><td>GET /history/astp/astp-patch-small.gif HTTP/1.0</td><td>200</td><td>18528</td></tr><tr><td>star1.stsci.edu</td><td>-</td><td>-</td><td>[28/Jul/1995:13:16:26</td><td>-0400]</td><td>GET /history/apollo/images/apollo-logo.gif HTTP/1.0</td><td>200</td><td>3047</td></t ...

# %%
df_py = df[df['_c6']=='HTTP/1.0\"']
df_py.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------------+---+---+--------------------+------+--------------------+---------+---+
#                  _c0|_c1|_c2|                 _c3|   _c4|                 _c5|      _c6|_c7|
# +--------------------+---+---+--------------------+------+--------------------+---------+---+
#       frank.mtsu.edu|  -|  -|[03/Jul/1995:02:4...|-0400]|        GET /images/|HTTP/1.0&#34;|404|
#       frank.mtsu.edu|  -|  -|[03/Jul/1995:02:4...|-0400]|        GET /images/|HTTP/1.0&#34;|404|
#       frank.mtsu.edu|  -|  -|[03/Jul/1995:02:4...|-0400]|        GET /images/|HTTP/1.0&#34;|404|
#       frank.mtsu.edu|  -|  -|[03/Jul/1995:02:5...|-0400]|         GET /images|HTTP/1.0&#34;|404|
#       141.102.80.253|  -|  -|[07/Jul/1995:11:5...|-0400]|GET /history/apol...|HTTP/1.0&#34;|404|
#       141.102.80.130|  -|  -|[12/Jul/1995:13:4...|-0400]|GET /history/apol...|HTTP/1.0&#34;|404|
#       141.102.80.130|  -|  -|[13/Jul/1995:19:2...|-0400]|GET /history/apol...|HTTP/1.0&#34;|404|
# ris1_u27.rsoc.roc...|  -|  -|[14/Jul/1995:10:3...|-0400]|GET /history/apol...|HTTP/1.0&#34;|404|
# piweba3y.prodigy.com|  -|  -|[14/Jul/1995:23:4...|-0400]|&#34;GET /history/app...|HTTP/1.0&#34;|404|
# arc.dental.upenn.edu|  -|  -|[18/Jul/1995:11:5...|-0400]|&#34;GET /elv/elvpage...|HTTP/1.0&#34;|403|
#       198.146.162.30|  -|  -|[19/Jul/1995:09:3...|-0400]|GET /history/apol...|HTTP/1.0&#34;|404|
#       138.13.123.210|  -|  -|[21/Jul/1995:13:2...|-0400]|GET /elv/ATLAS_CE...|HTTP/1.0&#34;|404|
#       138.13.123.210|  -|  -|[21/Jul/1995:13:2...|-0400]|GET /elv/ATLAS_CE...|HTTP/1.0&#34;|404|
# +--------------------+---+---+--------------------+------+--------------------+---------+---+
#
# </div>

# %%
get_list = []
request_list1 = []
request_list2 = []
invalid = []
a = ''
b = ''
c = ''

for element in my_list: 
    #print('element = ',element)
    if element != None:
        get = element.split()
        #print('get = ',get)
        if len(get) >= 4:
            print('get = ',get)
            invalid.append(get)
        if len(get) == 3:
            a = get[0]
            b = get[1]
            c = get[2]
            get_list.append(a)
            request_list1.append(b)
            request_list2.append(c)
        elif len(get) == 2:
            a = get[0]
            b = get[1]
            c = 'NaN'
            get_list.append(a)
            request_list1.append(b)
            request_list2.append(c)
        elif len(get) == 1:
            match = re.match('\d',get[0])
            if match == None:
                a = get[0]
                b = 'NaN'
                c = 'NaN'
                get_list.append(a)
                request_list1.append(b)
                request_list2.append(c)
            else:
                a = 'NaN'
                b = get[0]
                c = 'NaN'
                get_list.append(a)
                request_list1.append(b)
                request_list2.append(c)
        else:
            a = 'NaN'
            b = 'NaN'
            c = 'NaN'
            get_list.append(a)
            request_list1.append(b)
            request_list2.append(c)
    else:
        a = 'NaN'
        b = 'NaN'
        c = 'NaN'
        get_list.append(a)
        request_list1.append(b)
        request_list2.append(c)
        
        

#print(get_list)
#print(request_list1)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">get =  [&#39;GET&#39;, &#39;/history/history.html&#39;, &#39;hqpao/hqpao_home.html&#39;, &#39;HTTP/1.0&#39;]
# get =  [&#39;GET&#39;, &#39;/shuttle/missions/missions.html&#39;, &#39;Shuttle&#39;, &#39;Launches&#39;, &#39;from&#39;, &#39;Kennedy&#39;, &#39;Space&#39;, &#39;Center&#39;, &#39;HTTP/1.0&#39;]
# get =  [&#39;GET&#39;, &#39;/finger&#39;, &#39;@net.com&#39;, &#39;HTTP/1.0&#39;]
# get =  [&#39;GET&#39;, &#39;/htbin/wais.pl?orbit&#39;, &#39;sts71&#39;, &#39;HTTP/1.0&#39;]
# get =  [&#39;GET&#39;, &#39;/&#39;, &#39;/&#39;, &#39;HTTP/1.0&#39;]
# get =  [&#39;GET&#39;, &#39;/&#39;, &#39;/facts/facts.html&#39;, &#39;HTTP/1.0&#39;]
# get =  [&#39;GET&#39;, &#39;/htbin/wais.pl?Wake&#39;, &#39;Shield&#39;, &#39;HTTP/1.0&#39;]
# get =  [&#39;GET&#39;, &#39;/shuttle/countdown/dy&#39;, &#39;�?shuttle%20tracking&#39;, &#39;HTTP/1.0&#39;]
# get =  [&#39;GET&#39;, &#39;/shuttle/countdown/dy&#39;, &#39;�?tracking%20station&#39;, &#39;HTTP/1.0&#39;]
# get =  [&#39;GET&#39;, &#39;/&#39;, &#39;/&#39;, &#39;HTTP/1.0&#39;]
# get =  [&#39;GET&#39;, &#39;/images/NASA-logosmall.gif&#39;, &#39;align=left&#39;, &#39;HTTP/1.0&#39;]
# get =  [&#39;GET&#39;, &#39;/images/NASA-logosmall.gif&#39;, &#39;align=left&#39;, &#39;HTTP/1.0&#39;]
# get =  [&#39;GET&#39;, &#39;/images/NASA-logosmall.gif&#39;, &#39;align=left&#39;, &#39;HTTP/1.0&#39;]
# get =  [&#39;GET&#39;, &#39;/images/NASA-logosmall.gif&#39;, &#39;align=left&#39;, &#39;HTTP/1.0&#39;]
# get =  [&#39;GET&#39;, &#39;/images/NASA-logosmall.gif&#39;, &#39;align=left&#39;, &#39;HTTP/1.0&#39;]
# get =  [&#39;GET&#39;, &#39;/images/NASA-logosmall.gif&#39;, &#39;align=left&#39;, &#39;HTTP/1.0&#39;]
# get =  [&#39;GET&#39;, &#39;/images/NASA-logosmall.gif&#39;, &#39;align=left&#39;, &#39;HTTP/1.0&#39;]
# get =  [&#39;GET&#39;, &#39;/images/NASA-logosmall.gif&#39;, &#39;align=left&#39;, &#39;HTTP/1.0&#39;]
# get =  [&#39;GET&#39;, &#39;/images/NASA-logosmall.gif&#39;, &#39;align=left&#39;, &#39;HTTP/1.0&#39;]
# get =  [&#39;GET&#39;, &#39;/images/NASA-logosmall.gif&#39;, &#39;align=left&#39;, &#39;HTTP/1.0&#39;]
# get =  [&#39;GET&#39;, &#39;/images/NASA-logosmall.gif&#39;, &#39;align=left&#39;, &#39;HTTP/1.0&#39;]
# get =  [&#39;GET&#39;, &#39;/images/NASA-logosmall.gif&#39;, &#39;align=left&#39;, &#39;HTTP/1.0&#39;]
# get =  [&#39;GET&#39;, &#39;/images/NASA-logosmall.gif&#39;, &#39;align=left&#39;, &#39;HTTP/1.0&#39;]
# get =  [&#39;GET&#39;, &#39;/images/NASA-logosmall.gif&#39;, &#39;align=left&#39;, &#39;HTTP/1.0&#39;]
# get =  [&#39;GET&#39;, &#39;/images/NASA-logosmall.gif&#39;, &#39;align=left&#39;, &#39;HTTP/1.0&#39;]
# get =  [&#39;GET&#39;, &#39;/images/NASA-logosmall.gif&#39;, &#39;align=left&#39;, &#39;HTTP/1.0&#39;]
# get =  [&#39;GET&#39;, &#39;/images/NASA-logosmall.gif&#39;, &#39;align=left&#39;, &#39;HTTP/1.0&#39;]
# get =  [&#39;GET&#39;, &#39;/images/NASA-logosmall.gif&#39;, &#39;align=left&#39;, &#39;HTTP/1.0&#39;]
# get =  [&#39;GET&#39;, &#39;/images/NASA-logosmall.gif&#39;, &#39;align=left&#39;, &#39;HTTP/1.0&#39;]
# get =  [&#39;GET&#39;, &#39;/images/NASA-logosmall.gif&#39;, &#39;align=left&#39;, &#39;HTTP/1.0&#39;]
# get =  [&#39;GET&#39;, &#39;/images/NASA-logosmall.gif&#39;, &#39;align=left&#39;, &#39;HTTP/1.0&#39;]
# get =  [&#39;GET&#39;, &#39;/images/NASA-logosmall.gif&#39;, &#39;align=left&#39;, &#39;HTTP/1.0&#39;]
# get =  [&#39;GET&#39;, &#39;/images/NASA-logosmall.gif&#39;, &#39;align=left&#39;, &#39;HTTP/1.0&#39;]
# get =  [&#39;GET&#39;, &#39;/images/NASA-logosmall.gif&#39;, &#39;align=left&#39;, &#39;HTTP/1.0&#39;]
# get =  [&#39;GET&#39;, &#39;/images/NASA-logosmall.gif&#39;, &#39;align=left&#39;, &#39;HTTP/1.0&#39;]
# get =  [&#39;GET&#39;, &#39;/images/NASA-logosmall.gif&#39;, &#39;align=left&#39;, &#39;HTTP/1.0&#39;]
# get =  [&#39;GET&#39;, &#39;/images/NASA-logosmall.gif&#39;, &#39;align=left&#39;, &#39;HTTP/1.0&#39;]
# get =  [&#39;GET&#39;, &#39;/images/NASA-logosmall.gif&#39;, &#39;align=left&#39;, &#39;HTTP/1.0&#39;]
# get =  [&#39;GET&#39;, &#39;/images/NASA-logosmall.gif&#39;, &#39;align=left&#39;, &#39;HTTP/1.0&#39;]
# get =  [&#39;GET&#39;, &#39;/images/NASA-logosmall.gif&#39;, &#39;align=left&#39;, &#39;HTTP/1.0&#39;]
# get =  [&#39;GET&#39;, &#39;/images/NASA-logosmall.gif&#39;, &#39;align=left&#39;, &#39;HTTP/1.0&#39;]
# get =  [&#39;GET&#39;, &#39;/images/NASA-logosmall.gif&#39;, &#39;align=left&#39;, &#39;HTTP/1.0&#39;]
# get =  [&#39;GET&#39;, &#39;/images/NASA-logosmall.gif&#39;, &#39;align=left&#39;, &#39;HTTP/1.0&#39;]
# get =  [&#39;GET&#39;, &#39;/images/NASA-logosmall.gif&#39;, &#39;align=left&#39;, &#39;HTTP/1.0&#39;]
# get =  [&#39;GET&#39;, &#39;/images/NASA-logosmall.gif&#39;, &#39;align=left&#39;, &#39;HTTP/1.0&#39;]
# get =  [&#39;GET&#39;, &#39;/images/NASA-logosmall.gif&#39;, &#39;align=left&#39;, &#39;HTTP/1.0&#39;]
# get =  [&#39;GET&#39;, &#39;/images/NASA-logosmall.gif&#39;, &#39;align=left&#39;, &#39;HTTP/1.0&#39;]
# get =  [&#39;GET&#39;, &#39;/images/NASA-logosmall.gif&#39;, &#39;align=left&#39;, &#39;HTTP/1.0&#39;]
# get =  [&#39;GET&#39;, &#39;/images/NASA-logosmall.gif&#39;, &#39;align=left&#39;, &#39;HTTP/1.0&#39;]
# get =  [&#39;GET&#39;, &#39;/images/NASA-logosmall.gif&#39;, &#39;align=left&#39;, &#39;HTTP/1.0&#39;]
# get =  [&#39;GET&#39;, &#39;/images/NASA-logosmall.gif&#39;, &#39;align=left&#39;, &#39;HTTP/1.0&#39;]
# get =  [&#39;GET&#39;, &#39;
#39;[01/Jul/1995:00:01:51-0400]&#39;, &#39;[01/Jul/1995:00:01:52-0400]&#39;, &#39;[01/Jul/1995:00:01:52-0400]&#39;, &#39;[01/Jul/1995:00:01:52-0400]&#39;, &#39;[01/Jul/1995:00:01:52-0400]&#39;, &#39;[01/Jul/1995:00:01:53-0400]&#39;, &#39;[01/Jul/1995:00:01:55-0400]&#39;, &#39;[01/Jul/1995:00:01:55-0400]&#39;, &#39;[01/Jul/1995:00:01:55-0400]&#39;, &#39;[01/Jul/1995:00:01:56-0400]&#39;, &#39;[01/Jul/1995:00:01:57-0400]&#39;, &#39;[01/Jul/1995:00:01:57-0400]&#39;, &#39;[01/Jul/1995:00:01:58-0400]&#39;, &#39;[01/Jul/1995:00:01:58-0400]&#39;, &#39;[01/Jul/1995:00:01:58-0400]&#39;, &#39;[01/Jul/1995:00:01:58-0400]&#39;, &#39;[01/Jul/1995:00:01:59-0400]&#39;, &#39;[01/Jul/1995:00:01:59-0400]&#39;,  ...

# %%
# convert lists into pyspark dataframe

s1 = pd.Series(my_list2)
s2 = pd.Series(my_new_list)
s3 = pd.Series(my_list5)
s4 = pd.Series(get_list)
s5 = pd.Series(request_list1)
s6 = pd.Series(request_list2)
s7 = pd.Series(my_list6)
s8 = pd.Series(my_list3)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# # Pandas DataFrame formed using series

# %%
#new_df = pd.DataFrame(data = [s1,s2,s3], columns=['type','req1','req2'])
new_df = pd.DataFrame({'host': s1,'timestamp': s2, 'method': s4, 'endpoint': s5, 'protocol': s6,  'http_status': s7, 'content_size': s8})
print(new_df)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">                         host  ... content_size
# 0                199.72.81.55  ...         6245
# 1        unicomp6.unicomp.net  ...         3985
# 2              199.120.110.21  ...         4085
# 3          burger.letters.com  ...            0
# 4              199.120.110.21  ...         4179
# ...                       ...  ...          ...
# 1891710         163.205.53.14  ...         1204
# 1891711    tiger2.ocs.lsu.edu  ...         8677
# 1891712            199.0.2.27  ...         5866
# 1891713       tornado.umd.edu  ...         5494
# 1891714              alyssa.p  ...         None
#
# [1891715 rows x 7 columns]
# </div>

# %% [markdown]
# # Replacing the method type with the correct one

# %%
new_df['method'].replace(to_replace ="\"GET",
                 value ="GET", inplace=True)
#a_df = new_df[new_df['method'] == '"GET']
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
new_df['domain_name'] = new_df['host'].str.extract(r'(\.com|\.jp|\.net|\.gov|\.edu|\.ca|\.au|\.de|\.nz|\.uk|\.mil|\.sg|\.no|\.se|\.it|\.be|\.dk|\.org|\.ni|\.fr|\.fi|\.si|\.nl|\.arpa|\.ch|\.kr|\.za|\.su|\.at|\.lu|\.pl|\.il|\.es|\.cz|\.us|\.ar|\.mt|\.is|\.pt|\.my|\.ee|\.cl|\.gr|\.ie|\.mx|\.cr|\.br|\.ru|\.int|\.ve|\.cn|\.hu|\.gb|\.sk|\.pa|\.ge|\.bm)')
print(df_new.head(700))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">                     host                    timestamp  ... content_size domain_name
# 0       in24.inetnebr.com  [01/Aug/1995:00:00:01-0400]  ...         1839        .com
# 1         uplherc.upl.com  [01/Aug/1995:00:00:07-0400]  ...            0        .com
# 2         uplherc.upl.com  [01/Aug/1995:00:00:08-0400]  ...            0        .com
# 3         uplherc.upl.com  [01/Aug/1995:00:00:08-0400]  ...            0        .com
# 4         uplherc.upl.com  [01/Aug/1995:00:00:08-0400]  ...            0        .com
# ..                    ...                          ...  ...          ...         ...
# 695  piweba1y.prodigy.com  [01/Aug/1995:00:24:46-0400]  ...         1713        .com
# 696         133.43.106.47  [01/Aug/1995:00:24:50-0400]  ...          786         NaN
# 697         ras15.srv.net  [01/Aug/1995:00:24:57-0400]  ...         8677        .net
# 698         133.43.106.47  [01/Aug/1995:00:25:00-0400]  ...          363         NaN
# 699         ras15.srv.net  [01/Aug/1995:00:25:01-0400]  ...        11853        .net
#
# [700 rows x 8 columns]
# </div>

# %%
new_df['domain_name'].replace(to_replace =np.NaN,
                 value ="IP Address", inplace=True)

new_df
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[202]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>host</th>
#       <th>timestamp</th>
#       <th>method</th>
#       <th>endpoint</th>
#       <th>protocol</th>
#       <th>http_status</th>
#       <th>content_size</th>
#       <th>domain_name</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>199.72.81.55</td>
#       <td>[01/Jul/1995:00:00:01-0400]</td>
#       <td>GET</td>
#       <td>/history/apollo/</td>
#       <td>HTTP/1.0</td>
#       <td>200</td>
#       <td>6245</td>
#       <td>IP Address</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>unicomp6.unicomp.net</td>
#       <td>[01/Jul/1995:00:00:06-0400]</td>
#       <td>GET</td>
#       <td>/shuttle/countdown/</td>
#       <td>HTTP/1.0</td>
#       <td>200</td>
#       <td>3985</td>
#       <td>.net</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>199.120.110.21</td>
#       <td>[01/Jul/1995:00:00:09-0400]</td>
#       <td>GET</td>
#       <td>/shuttle/missions/sts-73/mission-sts-73.html</td>
#       <td>HTTP/1.0</td>
#       <td>200</td>
#       <td>4085</td>
#       <td>IP Address</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>burger.letters.com</td>
#       <td>[01/Jul/1995:00:00:11-0400]</td>
#       <td>GET</td>
#       <td>/shuttle/countdown/liftoff.html</td>
#       <td>HTTP/1.0</td>
#       <td>304</td>
#       <td>0</td>
#       <td>.com</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>199.120.110.21</td>
#       <td>[01/Jul/1995:00:00:11-0400]</td>
#       <td>GET</td>
#       <td>/shuttle/missions/sts-73/sts-73-patch-small.gif</td>
#       <td>HTTP/1.0</td>
#       <td>200</td>
#       <td>4179</td>
#       <td>IP Address</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>1891710</th>
#       <td>163.205.53.14</td>
#       <td>[28/Jul/1995:13:32:23-0400]</td>
#       <td>GET</td>
#       <td>/images/KSC-logosmall.gif</td>
#       <td>HTTP/1.0</td>
#       <td>200</td>
#       <td>1204</td>
#       <td>IP Address</td>
#     </tr>
#     <tr>
#       <th>1891711</th>
#       <td>tiger2.ocs.lsu.edu</td>
#       <td>[28/Jul/1995:13:32:23-0400]</td>
#       <td>GET</td>
#       <td>/shuttle/missions/missions.html</td>
#       <td>HTTP/1.0</td>
#       <td>200</td>
#       <td>8677</td>
#       <td>.edu</td>
#     </tr>
#     <tr>
#       <th>1891712</th>
#       <td>199.0.2.27</td>
#       <td>[28/Jul/1995:13:32:23-0400]</td>
#       <td>GET</td>
#       <td>/images/ksclogo-medium.gif</td>
#       <td>HTTP/1.0</td>
#       <td>200</td>
#       <td>5866</td>
#       <td>IP Address</td>
#     </tr>
#     <tr>
#       <th>1891713</th>
#       <td>tornado.umd.edu</td>
#       <td>[28/Jul/1995:13:32:25-0400]</td>
#       <td>GET</td>
#       <td>/shuttle/missions/sts-74/sts-74-patch-small.gif</td>
#       <td>HTTP/1.0</td>
#       <td>200</td>
#       <td>5494</td>
#       <td>.edu</td>
#     </tr>
#     <tr>
#       <th>1891714</th>
#       <td>alyssa.p</td>
#       <td>NoneNone</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>None</td>
#       <td>None</td>
#       <td>IP Address</td>
#     </tr>
#   </tbody>
# </table>
# <p>1891715 rows × 8 columns</p>
# </div>

# %% [markdown]
# # Created the PySpark DataFrame

# %%
spark_df = spark.createDataFrame(new_df)
display(spark_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>host</th><th>timestamp</th><th>method</th><th>endpoint</th><th>protocol</th><th>http_status</th><th>content_size</th><th>domain_name</th></tr></thead><tbody><tr><td>199.72.81.55</td><td>[01/Jul/1995:00:00:01-0400]</td><td>GET</td><td>/history/apollo/</td><td>HTTP/1.0</td><td>200</td><td>6245</td><td>IP Address</td></tr><tr><td>unicomp6.unicomp.net</td><td>[01/Jul/1995:00:00:06-0400]</td><td>GET</td><td>/shuttle/countdown/</td><td>HTTP/1.0</td><td>200</td><td>3985</td><td>.net</td></tr><tr><td>199.120.110.21</td><td>[01/Jul/1995:00:00:09-0400]</td><td>GET</td><td>/shuttle/missions/sts-73/mission-sts-73.html</td><td>HTTP/1.0</td><td>200</td><td>4085</td><td>IP Address</td></tr><tr><td>burger.letters.com</td><td>[01/Jul/1995:00:00:11-0400]</td><td>GET</td><td>/shuttle/countdown/liftoff.html</td><td>HTTP/1.0</td><td>304</td><td>0</td><td>.com</td></tr><tr><td>199.120.110.21</td><td>[01/Jul/1995:00:00:11-0400]</td><td>GET</td><td>/shuttle/missions/sts-73/sts-73-patch-small.gif</td><td>HTTP/1.0</td><td>200</td><td>4179</td><td>IP Address</td></tr><tr><td>burger.letters.com</td><td>[01/Jul/1995:00:00:12-0400]</td><td>GET</td><td>/images/NASA-logosmall.gif</td><td>HTTP/1.0</td><td>304</td><td>0</td><td>.com</td></tr><tr><td>burger.letters.com</td><td>[01/Jul/1995:00:00:12-0400]</td><td>GET</td><td>/shuttle/countdown/video/livevideo.gif</td><td>HTTP/1.0</td><td>200</td><td>0</td><td>.com</td></tr><tr><td>205.212.115.106</td><td>[01/Jul/1995:00:00:12-0400]</td><td>GET</td><td>/shuttle/countdown/countdown.html</td><td>HTTP/1.0</td><td>200</td><td>3985</td><td>IP Address</td></tr><tr><td>d104.aa.net</td><td>[01/Jul/1995:00:00:13-0400]</td><td>GET</td><td>/shuttle/countdown/</td><td>HTTP/1.0</td><td>200</td><td>3985</td><td>.net</td></tr><tr><td>129.94.144.152</td><td>[01/Jul/1995:00:00:13-0400]</td><td>GET</td><td>/</td><td>HTTP/1.0</td><td>200</td><td>7074</td><td>IP Address</td></tr><tr><td>unicomp6.unicomp.net</td><td>[01/Jul/1995:00:00:14-0400]</td><td>GET</td><td>/shuttle/countdown/count.gif</td><td>HTTP/1.0</td><td>200</td><td>40310</td><td>.net</td></tr><tr><td>unicomp6.unicomp.net</td><td>[01/Jul/1995:00:00:14-0400]</td><td>GET</td><td>/images/NASA-logosmall.gif</td><td>HTTP/1.0</td><td>200</td><td>786</td><td>.net</td></tr><tr><td>unicomp6.unicomp.net</td><td>[01/Jul/1995:00:00:14-0400]</td><td>GET</td><td>/images/KSC-logosmall.gif</td><td>HTTP/1.0</td><td>200</td><td>1204</td><td>.net</td></tr><tr><td>d104.aa.net</td><td>[01/Jul/1995:00:00:15-0400]</td><td>GET</td><td>/shuttle/countdown/count.gif</td><td>HTTP/1.0</td><td>200</td><td>40310</td><td>.net</td></tr><tr><td>d104.aa.net</td><td>[01/Jul/1995:00:00:15-0400]</td><td>GET</td><td>/images/NASA-logosmall.gif</td><td>HTTP/1.0</td><td>200</td><td>786</td><td>.net</td></tr><tr><td>d104.aa.net</td><td>[01/Jul/1995:00:00:15-0400]</td><td>GET</td><td>/images/KSC-logosmall.gif</td><td>HTTP/1.0</td><td>200</td><td>1204</td><td>.net</td></tr><tr><td>129.94.144.152</td><td>[01/Jul/1995:00:00:17-0400]</td><td>GET</td><td>/images/ksclogo-medium.gif</td><td>HTTP/1.0</td><td>304</td><td>0</td><td>IP Address</td></tr><tr><td>199.120.110.21</td><td>[01/Jul/1995:00:00:17-0400]</td><td>GET</td><td>/images/launch-logo.gif</td><td>HTTP/1.0</td><td>200</td><td>1713</td><td>IP Address</td></tr><tr><td>ppptky391.asahi-net.or.jp</td><td>[01/Jul/1995:00:00:18-0400]</td><td>GET</td><td>/facts/about_ksc.html</td><td>HTTP/1.0</td><td>200</td><td>3977</td><td>.jp</td></tr><tr><td>net-1-141.eden.com</td><td>[01/Jul/1995:00:00:19-0400]</td><td>GET</td><td>/shuttle/missions/sts-71/images/KSC-95EC-0916.jpg</td><td>HTTP/1.0</td><td>200</td><td>34029</td><td>.com</td></tr><tr><td>ppptky391.asahi-net.or.jp</td><td>[01/Jul/1995:00:00:19-0400]</td><td>GET</td><td>/images/launchpalms-small.gif</td><td>HTTP/1.0</td><td>200</td><td>11473</td><td>.jp</td></tr><tr><td>205.189.154.54</td><td>[01/Jul/19 ...

# %% [markdown]
# # Named the PySpark DataFrame to be used in SQL

# %%
spark_df.registerTempTable("df_final")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
sqldf1 = spark.sql("SELECT host, timestamp, method, endpoint, protocol, http_status, content_size, domain_name FROM df_final WHERE http_status = 'HTTP/1.0\"'")
sqldf1.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------------+--------------------+------+--------------------+--------+-----------+------------+-----------+
#                 host|           timestamp|method|            endpoint|protocol|http_status|content_size|domain_name|
# +--------------------+--------------------+------+--------------------+--------+-----------+------------+-----------+
#       frank.mtsu.edu|[03/Jul/1995:02:4...|   GET|            /images/|     NaN|  HTTP/1.0&#34;|         404|        .mt|
#       frank.mtsu.edu|[03/Jul/1995:02:4...|   GET|            /images/|     NaN|  HTTP/1.0&#34;|         404|        .mt|
#       frank.mtsu.edu|[03/Jul/1995:02:4...|   GET|            /images/|     NaN|  HTTP/1.0&#34;|         404|        .mt|
#       frank.mtsu.edu|[03/Jul/1995:02:5...|   GET|             /images|     NaN|  HTTP/1.0&#34;|         404|        .mt|
#       141.102.80.253|[07/Jul/1995:11:5...|   GET|/history/apollo/a...|     NaN|  HTTP/1.0&#34;|         404| IP Address|
#       141.102.80.130|[12/Jul/1995:13:4...|   GET|/history/apollo/a...|     NaN|  HTTP/1.0&#34;|         404| IP Address|
#       141.102.80.130|[13/Jul/1995:19:2...|   GET|/history/apollo/a...|     NaN|  HTTP/1.0&#34;|         404| IP Address|
# ris1_u27.rsoc.roc...|[14/Jul/1995:10:3...|   GET|/history/apollo/a...|     NaN|  HTTP/1.0&#34;|         404|       .com|
# piweba3y.prodigy.com|[14/Jul/1995:23:4...|   GET|/history/appollo/...|     NaN|  HTTP/1.0&#34;|         404|       .com|
# arc.dental.upenn.edu|[18/Jul/1995:11:5...|   GET|/elv/elvpage.htm/...|     NaN|  HTTP/1.0&#34;|         403|        .de|
#       198.146.162.30|[19/Jul/1995:09:3...|   GET|/history/apollo/a...|     NaN|  HTTP/1.0&#34;|         404| IP Address|
#       138.13.123.210|[21/Jul/1995:13:2...|   GET|/elv/ATLAS_CENTAU...|     NaN|  HTTP/1.0&#34;|         404| IP Address|
#       138.13.123.210|[21/Jul/1995:13:2...|   GET|/elv/ATLAS_CENTAU...|     NaN|  HTTP/1.0&#34;|         404| IP Address|
# +--------------------+--------------------+------+--------------------+--------+-----------+------------+-----------+
#
# </div>

# %% [markdown]
# # SQL used to create a table

# %%
# %sql
SELECT *
FROM df_final
--WHERE (method != 'GET') and (method != 'HEAD') and (method != 'POST')
GROUP BY host, timestamp, method, endpoint, protocol, http_status, content_size, domain_name
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>host</th><th>timestamp</th><th>method</th><th>endpoint</th><th>protocol</th><th>http_status</th><th>content_size</th><th>domain_name</th></tr></thead><tbody><tr><td>daddy-bock.tamu.edu</td><td>[02/Jul/1995:22:12:50-0400]</td><td>GET</td><td>/images/NASA-logosmall.gif</td><td>HTTP/1.0</td><td>200</td><td>786</td><td>.edu</td></tr><tr><td>ts4-16.inforamp.net</td><td>[02/Jul/1995:22:17:24-0400]</td><td>GET</td><td>/images/NASA-logosmall.gif</td><td>HTTP/1.0</td><td>304</td><td>0</td><td>.net</td></tr><tr><td>199.172.50.40</td><td>[02/Jul/1995:22:28:47-0400]</td><td>GET</td><td>/shuttle/countdown/liftoff.html</td><td>HTTP/1.0</td><td>200</td><td>4538</td><td>IP Address</td></tr><tr><td>soc12.socsci.unc.edu</td><td>[02/Jul/1995:22:30:33-0400]</td><td>GET</td><td>/shuttle/technology/images/sts_body_2-small.gif</td><td>HTTP/1.0</td><td>200</td><td>30067</td><td>.edu</td></tr><tr><td>knownet.cpbi.org</td><td>[02/Jul/1995:22:16:06-0400]</td><td>GET</td><td>/shuttle/countdown/</td><td>HTTP/1.0</td><td>200</td><td>3985</td><td>.org</td></tr><tr><td>ts4-16.inforamp.net</td><td>[02/Jul/1995:22:18:18-0400]</td><td>GET</td><td>/cgi-bin/imagemap/countdown?316,276</td><td>HTTP/1.0</td><td>302</td><td>98</td><td>.net</td></tr><tr><td>ix-mvo-ca1-20.ix.netcom.com</td><td>[02/Jul/1995:22:19:01-0400]</td><td>GET</td><td>/cgi-bin/imagemap/countdown?103,168</td><td>HTTP/1.0</td><td>302</td><td>110</td><td>.net</td></tr><tr><td>ns26.moran.com</td><td>[02/Jul/1995:22:20:30-0400]</td><td>GET</td><td>/shuttle/missions/sts-71/images/images.html</td><td>HTTP/1.0</td><td>200</td><td>7634</td><td>.com</td></tr><tr><td>rvr0149.deltanet.com</td><td>[02/Jul/1995:22:21:10-0400]</td><td>GET</td><td>/shuttle/countdown/video/livevideo.gif</td><td>HTTP/1.0</td><td>200</td><td>57344</td><td>.de</td></tr><tr><td>mica.saglac.qc.ca</td><td>[02/Jul/1995:22:26:03-0400]</td><td>GET</td><td>/history/apollo/apollo-6/images/</td><td>HTTP/1.0</td><td>200</td><td>514</td><td>.ca</td></tr><tr><td>ix-mvo-ca1-20.ix.netcom.com</td><td>[02/Jul/1995:22:29:42-0400]</td><td>GET</td><td>/shuttle/missions/sts-71/sts-71-day-01-highlights.html</td><td>HTTP/1.0</td><td>200</td><td>2722</td><td>.net</td></tr><tr><td>www-b6.proxy.aol.com</td><td>[02/Jul/1995:22:30:34-0400]</td><td>GET</td><td>/history/apollo/images/apollo-small.gif</td><td>HTTP/1.0</td><td>200</td><td>9630</td><td>.com</td></tr><tr><td>pollux.cc.umanitoba.ca</td><td>[02/Jul/1995:22:16:35-0400]</td><td>GET</td><td>/shuttle/technology/images/srb_mod_compare_1-small.gif</td><td>HTTP/1.0</td><td>200</td><td>36902</td><td>.ca</td></tr><tr><td>ts4-16.inforamp.net</td><td>[02/Jul/1995:22:19:07-0400]</td><td>GET</td><td>/shuttle/countdown/video/livevideo.gif</td><td>HTTP/1.0</td><td>200</td><td>67373</td><td>.net</td></tr><tr><td>pipe2.nyc.pipeline.com</td><td>[02/Jul/1995:22:19:20-0400]</td><td>GET</td><td>/shuttle/missions/sts-71/sts-71-patch-small.gif</td><td>NaN</td><td>200</td><td>12054</td><td>.com</td></tr><tr><td>ts4-10.westwood.ts.ucla.edu</td><td>[02/Jul/1995:22:20:30-0400]</td><td>GET</td><td>/images/WORLD-logosmall.gif</td><td>HTTP/1.0</td><td>200</td><td>669</td><td>.edu</td></tr><tr><td>jodyscomp.tamu.edu</td><td>[02/Jul/1995:22:20:53-0400]</td><td>GET</td><td>/cgi-bin/imagemap/countdown?100,178</td><td>HTTP/1.0</td><td>302</td><td>110</td><td>.edu</td></tr><tr><td>mica.saglac.qc.ca</td><td>[02/Jul/1995:22:26:06-0400]</td><td>GET</td><td>/icons/blank.xbm</td><td>HTTP/1.0</td><td>304</td><td>0</td><td>.ca</td></tr><tr><td>198.70.174.196</td><td>[02/Jul/1995:22:17:11-0400]</td><td>GET</td><td>/shuttle/countdown/lps/fr.html</td><td>HTTP/1.0</td><td>200</td><td>1879</td><td>IP Address</td></tr><tr><td>pm18.sonic.net</td><td>[02/Jul/1995:22:18:06-0400]</td><td>GET</td><td>/</td><td>HTTP/1.0</td><td>200</td><td>7074</td><td>.net</td></tr><tr><td>maria-7a.aip.realtime.net</td><td>[02/Jul/1995:22:18:25-0400]</t ...

# %% [markdown]
# # SQL used to count the number of http methods

# %%
# %sql
SELECT method, COUNT(method) 
FROM df_final
GROUP BY method
ORDER BY method
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>method</th><th>count(method)</th></tr></thead><tbody><tr><td></td><td>1</td></tr><tr><td>GET</td><td>1886808</td></tr><tr><td>HEAD</td><td>3950</td></tr><tr><td>NaN</td><td>843</td></tr><tr><td>POST</td><td>111</td></tr><tr><td>k��tx��tG��t̓�</td><td>2</td></tr></tbody></table></div>

# %%
# %sql
SELECT *
FROM df_final
WHERE (method != 'GET') and (method != 'POST') and (method != 'HEAD')
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>host</th><th>timestamp</th><th>method</th><th>endpoint</th><th>protocol</th><th>http_status</th><th>content_size</th><th>domain_name</th></tr></thead><tbody><tr><td>204.120.229.63</td><td>[01/Jul/1995:04:29:05-0400]</td><td>NaN</td><td>NaN</td><td>NaN</td><td>200</td><td>1502</td><td>IP Address</td></tr><tr><td>nccse.gsfc.nasa.gov</td><td>[01/Jul/1995:07:36:13-0400]</td><td>NaN</td><td>NaN</td><td>NaN</td><td>200</td><td>8677</td><td>.gov</td></tr><tr><td>ix-nbw-nj1-22.ix.netcom.com</td><td>[01/Jul/1995:10:42:09-0400]</td><td>NaN</td><td>NaN</td><td>NaN</td><td>404</td><td>-</td><td>.net</td></tr><tr><td>gpotterpc.llnl.gov</td><td>[01/Jul/1995:22:26:51-0400]</td><td>NaN</td><td>NaN</td><td>NaN</td><td>200</td><td>317</td><td>.gov</td></tr><tr><td>wxs6-7.worldaccess.nl</td><td>[02/Jul/1995:08:09:27-0400]</td><td>NaN</td><td>NaN</td><td>NaN</td><td>200</td><td>7074</td><td>.nl</td></tr><tr><td>wxs6-7.worldaccess.nl</td><td>[02/Jul/1995:08:11:20-0400]</td><td>NaN</td><td>NaN</td><td>NaN</td><td>200</td><td>7074</td><td>.nl</td></tr><tr><td>s29.abqslip.indirect.com</td><td>[02/Jul/1995:14:24:26-0400]</td><td>NaN</td><td>NaN</td><td>NaN</td><td>200</td><td>7020</td><td>.com</td></tr><tr><td>pipe3.nyc.pipeline.com</td><td>[02/Jul/1995:22:24:41-0400]</td><td>NaN</td><td>NaN</td><td>NaN</td><td>404</td><td>-</td><td>.com</td></tr><tr><td>pipe3.nyc.pipeline.com</td><td>[02/Jul/1995:22:25:48-0400]</td><td>NaN</td><td>NaN</td><td>NaN</td><td>404</td><td>-</td><td>.com</td></tr><tr><td>wxs6-4.worldaccess.nl</td><td>[03/Jul/1995:08:14:40-0400]</td><td>NaN</td><td>NaN</td><td>NaN</td><td>304</td><td>0</td><td>.nl</td></tr><tr><td>atl4-m52.ed.ac.uk</td><td>[03/Jul/1995:09:31:12-0400]</td><td>NaN</td><td>NaN</td><td>NaN</td><td>200</td><td>786</td><td>.uk</td></tr><tr><td>atl4-m52.ed.ac.uk</td><td>[03/Jul/1995:09:32:20-0400]</td><td>NaN</td><td>NaN</td><td>NaN</td><td>200</td><td>786</td><td>.uk</td></tr><tr><td>atl4-m52.ed.ac.uk</td><td>[03/Jul/1995:09:32:47-0400]</td><td>NaN</td><td>NaN</td><td>NaN</td><td>200</td><td>786</td><td>.uk</td></tr><tr><td>atl4-m52.ed.ac.uk</td><td>[03/Jul/1995:09:33:50-0400]</td><td>NaN</td><td>NaN</td><td>NaN</td><td>200</td><td>786</td><td>.uk</td></tr><tr><td>atl4-m52.ed.ac.uk</td><td>[03/Jul/1995:09:35:27-0400]</td><td>NaN</td><td>NaN</td><td>NaN</td><td>200</td><td>786</td><td>.uk</td></tr><tr><td>atl4-m52.ed.ac.uk</td><td>[03/Jul/1995:09:36:21-0400]</td><td>NaN</td><td>NaN</td><td>NaN</td><td>200</td><td>786</td><td>.uk</td></tr><tr><td>atl4-m52.ed.ac.uk</td><td>[03/Jul/1995:09:38:23-0400]</td><td>NaN</td><td>NaN</td><td>NaN</td><td>200</td><td>786</td><td>.uk</td></tr><tr><td>atl4-m52.ed.ac.uk</td><td>[03/Jul/1995:09:39:10-0400]</td><td>NaN</td><td>NaN</td><td>NaN</td><td>200</td><td>786</td><td>.uk</td></tr><tr><td>atl4-m52.ed.ac.uk</td><td>[03/Jul/1995:09:40:08-0400]</td><td>NaN</td><td>NaN</td><td>NaN</td><td>200</td><td>786</td><td>.uk</td></tr><tr><td>atl4-m52.ed.ac.uk</td><td>[03/Jul/1995:09:44:39-0400]</td><td>NaN</td><td>NaN</td><td>NaN</td><td>200</td><td>786</td><td>.uk</td></tr><tr><td>atl4-m52.ed.ac.uk</td><td>[03/Jul/1995:09:45:34-0400]</td><td>NaN</td><td>NaN</td><td>NaN</td><td>200</td><td>786</td><td>.uk</td></tr><tr><td>atl4-m52.ed.ac.uk</td><td>[03/Jul/1995:09:50:04-0400]</td><td>NaN</td><td>NaN</td><td>NaN</td><td>200</td><td>786</td><td>.uk</td></tr><tr><td>atl4-m52.ed.ac.uk</td><td>[03/Jul/1995:09:50:27-0400]</td><td>NaN</td><td>NaN</td><td>NaN</td><td>200</td><td>786</td><td>.uk</td></tr><tr><td>atl4-m52.ed.ac.uk</td><td>[03/Jul/1995:09:52:38-0400]</td><td>NaN</td><td>NaN</td><td>NaN</td><td>200</td><td>786</td><td>.uk</td></tr><tr><td>atl4-m52.ed.ac.uk</td><td>[03/Jul/1995:09:53:40-0400]</td><td>NaN</td><td>NaN</td><td>NaN</td><td>200</td><td>786</td><td>.uk</td></tr><tr><td>atl4-m52.ed.ac.uk</td><td>[03/Jul/1995:09:59:59-0400]</td><td>NaN</td><td>NaN</td><td>NaN</t ...

# %% [markdown]
# # count number of methods for invalid endpoints - '/'

# %%
# %sql
SELECT method, endpoint, COUNT(endpoint)
FROM df_final
WHERE endpoint = '/' and (method = 'GET' or method = 'POST')
GROUP BY method, endpoint
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>method</th><th>endpoint</th><th>count(endpoint)</th></tr></thead><tbody><tr><td>GET</td><td>/</td><td>32709</td></tr><tr><td>POST</td><td>/</td><td>2</td></tr></tbody></table></div>

# %% [markdown]
# # Identify the HTTP status and assign response

# %%
# %sql
--SELECT OrderID, Quantity,
--CASE
--    WHEN Quantity > 30 THEN 'The quantity is greater than 30'
--    WHEN Quantity = 30 THEN 'The quantity is 30'
--    ELSE 'The quantity is under 30'
--END AS QuantityText
--FROM OrderDetails;

SELECT http_status, COUNT(http_status) as number_of_http_status, 
CASE 
            WHEN http_status = '200' THEN 'OK'
            WHEN http_status = '302' THEN 'FOUND'
            WHEN http_status = '304' THEN 'NOT MODIFIED'
            WHEN http_status = '400' THEN 'BAD REQUEST'
            WHEN http_status = '403' THEN 'FORBIDDEN'
            WHEN http_status = '404' THEN 'NOT FOUND'
            WHEN http_status = '500' THEN 'INTERNAL SERVICE ERROR'
            WHEN http_status = '501' THEN 'NOT IMPLEMENTED'
            WHEN http_status = 'HTTP/1.0\"' THEN 'FORBIDDEN or INVALID'
            WHEN http_status = 'of'  THEN 'INVALID'
END as HTTP_RESPONSE
FROM df_final
GROUP BY http_status
ORDER BY http_status
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>http_status</th><th>number_of_http_status</th><th>HTTP_RESPONSE</th></tr></thead><tbody><tr><td>null</td><td>0</td><td>null</td></tr><tr><td>200</td><td>1701534</td><td>OK</td></tr><tr><td>302</td><td>46573</td><td>FOUND</td></tr><tr><td>304</td><td>132627</td><td>NOT MODIFIED</td></tr><tr><td>400</td><td>5</td><td>BAD REQUEST</td></tr><tr><td>403</td><td>53</td><td>FORBIDDEN</td></tr><tr><td>404</td><td>10832</td><td>NOT FOUND</td></tr><tr><td>500</td><td>62</td><td>INTERNAL SERVICE ERROR</td></tr><tr><td>501</td><td>14</td><td>NOT IMPLEMENTED</td></tr><tr><td>HTTP/1.0"</td><td>13</td><td>FORBIDDEN or INVALID</td></tr><tr><td>of</td><td>1</td><td>INVALID</td></tr></tbody></table></div>

# %% [markdown]
# # Extract the http requests that has content size 0 or NULL

# %%
# %sql
SELECT *
FROM df_final
WHERE (content_size = '0') or (content_size is NULL)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>host</th><th>timestamp</th><th>method</th><th>endpoint</th><th>protocol</th><th>http_status</th><th>content_size</th><th>domain_name</th></tr></thead><tbody><tr><td>burger.letters.com</td><td>[01/Jul/1995:00:00:11-0400]</td><td>GET</td><td>/shuttle/countdown/liftoff.html</td><td>HTTP/1.0</td><td>304</td><td>0</td><td>.com</td></tr><tr><td>burger.letters.com</td><td>[01/Jul/1995:00:00:12-0400]</td><td>GET</td><td>/images/NASA-logosmall.gif</td><td>HTTP/1.0</td><td>304</td><td>0</td><td>.com</td></tr><tr><td>burger.letters.com</td><td>[01/Jul/1995:00:00:12-0400]</td><td>GET</td><td>/shuttle/countdown/video/livevideo.gif</td><td>HTTP/1.0</td><td>200</td><td>0</td><td>.com</td></tr><tr><td>129.94.144.152</td><td>[01/Jul/1995:00:00:17-0400]</td><td>GET</td><td>/images/ksclogo-medium.gif</td><td>HTTP/1.0</td><td>304</td><td>0</td><td>IP Address</td></tr><tr><td>onyx.southwind.net</td><td>[01/Jul/1995:00:01:39-0400]</td><td>GET</td><td>/images/KSC-logosmall.gif</td><td>HTTP/1.0</td><td>304</td><td>0</td><td>.net</td></tr><tr><td>netport-27.iu.net</td><td>[01/Jul/1995:00:02:00-0400]</td><td>GET</td><td>/images/ksclogo-medium.gif</td><td>HTTP/1.0</td><td>304</td><td>0</td><td>.net</td></tr><tr><td>netport-27.iu.net</td><td>[01/Jul/1995:00:02:01-0400]</td><td>GET</td><td>/images/NASA-logosmall.gif</td><td>HTTP/1.0</td><td>304</td><td>0</td><td>.net</td></tr><tr><td>netport-27.iu.net</td><td>[01/Jul/1995:00:02:01-0400]</td><td>GET</td><td>/images/MOSAIC-logosmall.gif</td><td>HTTP/1.0</td><td>304</td><td>0</td><td>.net</td></tr><tr><td>netport-27.iu.net</td><td>[01/Jul/1995:00:02:01-0400]</td><td>GET</td><td>/images/USA-logosmall.gif</td><td>HTTP/1.0</td><td>304</td><td>0</td><td>.net</td></tr><tr><td>netport-27.iu.net</td><td>[01/Jul/1995:00:02:04-0400]</td><td>GET</td><td>/images/WORLD-logosmall.gif</td><td>HTTP/1.0</td><td>304</td><td>0</td><td>.net</td></tr><tr><td>sneaker.oregoncoast.com</td><td>[01/Jul/1995:00:02:57-0400]</td><td>GET</td><td>/shuttle/countdown/</td><td>HTTP/1.0</td><td>304</td><td>0</td><td>.com</td></tr><tr><td>teleman.pr.mcs.net</td><td>[01/Jul/1995:00:02:58-0400]</td><td>GET</td><td>/msfc/astro_home.html</td><td>HTTP/1.0</td><td>304</td><td>0</td><td>.net</td></tr><tr><td>sneaker.oregoncoast.com</td><td>[01/Jul/1995:00:03:02-0400]</td><td>GET</td><td>/shuttle/countdown/count.gif</td><td>HTTP/1.0</td><td>304</td><td>0</td><td>.com</td></tr><tr><td>sneaker.oregoncoast.com</td><td>[01/Jul/1995:00:03:02-0400]</td><td>GET</td><td>/images/NASA-logosmall.gif</td><td>HTTP/1.0</td><td>304</td><td>0</td><td>.com</td></tr><tr><td>sneaker.oregoncoast.com</td><td>[01/Jul/1995:00:03:03-0400]</td><td>GET</td><td>/images/KSC-logosmall.gif</td><td>HTTP/1.0</td><td>304</td><td>0</td><td>.com</td></tr><tr><td>teleman.pr.mcs.net</td><td>[01/Jul/1995:00:03:56-0400]</td><td>GET</td><td>/shuttle/missions/missions.html</td><td>HTTP/1.0</td><td>304</td><td>0</td><td>.net</td></tr><tr><td>teleman.pr.mcs.net</td><td>[01/Jul/1995:00:03:57-0400]</td><td>GET</td><td>/images/launchmedium.gif</td><td>HTTP/1.0</td><td>304</td><td>0</td><td>.net</td></tr><tr><td>teleman.pr.mcs.net</td><td>[01/Jul/1995:00:03:57-0400]</td><td>GET</td><td>/images/NASA-logosmall.gif</td><td>HTTP/1.0</td><td>304</td><td>0</td><td>.net</td></tr><tr><td>teleman.pr.mcs.net</td><td>[01/Jul/1995:00:03:57-0400]</td><td>GET</td><td>/images/KSC-logosmall.gif</td><td>HTTP/1.0</td><td>304</td><td>0</td><td>.net</td></tr><tr><td>teleman.pr.mcs.net</td><td>[01/Jul/1995:00:04:31-0400]</td><td>GET</td><td>/images/launch-logo.gif</td><td>HTTP/1.0</td><td>304</td><td>0</td><td>.net</td></tr><tr><td>teleman.pr.mcs.net</td><td>[01/Jul/1995:00:05:20-0400]</td><td>GET</td><td>/shuttle/missions/sts-78/sts-78-patch-small.gif</td><td>HTTP/1.0</td><td>304</td><td>0</td><td>.net</td></tr><tr><td>burger.letters.com</td><td>[01/Jul/1995:00:06:12-0400]</td><td>GET</td><td>/shutt ...

# %% [markdown]
# # Extract the number of methods that has content = 0 or content = 'null'

# %%
# %sql 
SELECT method, COUNT(method) as number_of_methods, http_status, content_size
FROM df_final
WHERE (content_size = '0') or (content_size is NULL)
GROUP BY method, http_status, content_size
ORDER BY method, http_status
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>method</th><th>number_of_methods</th><th>http_status</th><th>content_size</th></tr></thead><tbody><tr><td>GET</td><td>2961</td><td>200</td><td>0</td></tr><tr><td>GET</td><td>20</td><td>302</td><td>0</td></tr><tr><td>GET</td><td>132626</td><td>304</td><td>0</td></tr><tr><td>GET</td><td>1</td><td>404</td><td>0</td></tr><tr><td>GET</td><td>62</td><td>500</td><td>0</td></tr><tr><td>HEAD</td><td>3941</td><td>200</td><td>0</td></tr><tr><td>HEAD</td><td>5</td><td>302</td><td>0</td></tr><tr><td>NaN</td><td>1</td><td>null</td><td>null</td></tr><tr><td>NaN</td><td>1</td><td>304</td><td>0</td></tr></tbody></table></div>

# %%
# %sql 
SELECT method, COUNT(method) as number_of_methods, http_status, content_size
FROM df_final
WHERE (content_size != '0')
GROUP BY method, http_status, content_size
ORDER BY method, http_status, content_size
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>method</th><th>number_of_methods</th><th>http_status</th><th>content_size</th></tr></thead><tbody><tr><td></td><td>1</td><td>400</td><td>-</td></tr><tr><td>GET</td><td>83</td><td>200</td><td>-</td></tr><tr><td>GET</td><td>1</td><td>200</td><td>1001</td></tr><tr><td>GET</td><td>7</td><td>200</td><td>100203</td></tr><tr><td>GET</td><td>5</td><td>200</td><td>100223</td></tr><tr><td>GET</td><td>34</td><td>200</td><td>100268</td></tr><tr><td>GET</td><td>35</td><td>200</td><td>100269</td></tr><tr><td>GET</td><td>205</td><td>200</td><td>10032</td></tr><tr><td>GET</td><td>63</td><td>200</td><td>10036</td></tr><tr><td>GET</td><td>4</td><td>200</td><td>1004</td></tr><tr><td>GET</td><td>47</td><td>200</td><td>100481</td></tr><tr><td>GET</td><td>20</td><td>200</td><td>1005</td></tr><tr><td>GET</td><td>13</td><td>200</td><td>10054</td></tr><tr><td>GET</td><td>143</td><td>200</td><td>1006</td></tr><tr><td>GET</td><td>1</td><td>200</td><td>10063</td></tr><tr><td>GET</td><td>6</td><td>200</td><td>100665</td></tr><tr><td>GET</td><td>1055</td><td>200</td><td>1007</td></tr><tr><td>GET</td><td>310</td><td>200</td><td>100705</td></tr><tr><td>GET</td><td>317</td><td>200</td><td>10072</td></tr><tr><td>GET</td><td>44</td><td>200</td><td>10075</td></tr><tr><td>GET</td><td>2</td><td>200</td><td>1007616</td></tr><tr><td>GET</td><td>2</td><td>200</td><td>10078</td></tr><tr><td>GET</td><td>2</td><td>200</td><td>10081</td></tr><tr><td>GET</td><td>63</td><td>200</td><td>100851</td></tr><tr><td>GET</td><td>37</td><td>200</td><td>1009</td></tr><tr><td>GET</td><td>1560</td><td>200</td><td>10099</td></tr><tr><td>GET</td><td>4</td><td>200</td><td>10102</td></tr><tr><td>GET</td><td>25</td><td>200</td><td>101087</td></tr><tr><td>GET</td><td>26</td><td>200</td><td>101095</td></tr><tr><td>GET</td><td>6</td><td>200</td><td>10113</td></tr><tr><td>GET</td><td>192</td><td>200</td><td>10116</td></tr><tr><td>GET</td><td>33</td><td>200</td><td>10118</td></tr><tr><td>GET</td><td>8</td><td>200</td><td>10119</td></tr><tr><td>GET</td><td>2</td><td>200</td><td>10120</td></tr><tr><td>GET</td><td>856</td><td>200</td><td>101267</td></tr><tr><td>GET</td><td>30</td><td>200</td><td>10133</td></tr><tr><td>GET</td><td>9</td><td>200</td><td>10135</td></tr><tr><td>GET</td><td>367</td><td>200</td><td>10136</td></tr><tr><td>GET</td><td>5</td><td>200</td><td>101360</td></tr><tr><td>GET</td><td>410</td><td>200</td><td>1013716</td></tr><tr><td>GET</td><td>1</td><td>200</td><td>10144</td></tr><tr><td>GET</td><td>1</td><td>200</td><td>101465</td></tr><tr><td>GET</td><td>23</td><td>200</td><td>101521</td></tr><tr><td>GET</td><td>19</td><td>200</td><td>101571</td></tr><tr><td>GET</td><td>1</td><td>200</td><td>1015808</td></tr><tr><td>GET</td><td>311</td><td>200</td><td>1016</td></tr><tr><td>GET</td><td>67</td><td>200</td><td>101647</td></tr><tr><td>GET</td><td>293</td><td>200</td><td>101688</td></tr><tr><td>GET</td><td>56</td><td>200</td><td>101691</td></tr><tr><td>GET</td><td>16</td><td>200</td><td>1018</td></tr><tr><td>GET</td><td>1</td><td>200</td><td>10183</td></tr><tr><td>GET</td><td>1</td><td>200</td><td>10184</td></tr><tr><td>GET</td><td>180</td><td>200</td><td>101950</td></tr><tr><td>GET</td><td>25</td><td>200</td><td>102016</td></tr><tr><td>GET</td><td>28</td><td>200</td><td>10205</td></tr><tr><td>GET</td><td>3</td><td>200</td><td>10222</td></tr><tr><td>GET</td><td>2</td><td>200</td><td>10228</td></tr><tr><td>GET</td><td>1</td><td>200</td><td>102326</td></tr><tr><td>GET</td><td>72</td><td>200</td><td>102358</td></tr><tr><td>GET</td><td>101</td><td>200</td><td>102381</td></tr><tr><td>GET</td><td>1</td><td>200</td><td>10240</td></tr><tr><td>GET</td><td>5</td><td>200</td><td>10249</td></tr><tr><td>GET</td><td>2</td><td>200</td><td>10283</td></tr><tr><td>GET</td><td>3</td><td>200</td><td>10285</td></tr><tr><td>GET</td><td>2</td><td>200</td><td>1029</td></tr><tr><td>GET</td>< ...

# %% [markdown]
# # Extract the domain_name and count number of domain_names

# %%
# %sql
SELECT domain_name, COUNT(domain_name) as number_of_domain_name
FROM df_final
GROUP BY domain_name
ORDER BY number_of_domain_name
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>domain_name</th><th>number_of_domain_name</th></tr></thead><tbody><tr><td>.arpa</td><td>177</td></tr><tr><td>.my</td><td>643</td></tr><tr><td>.ve</td><td>740</td></tr><tr><td>.gb</td><td>917</td></tr><tr><td>.cz</td><td>951</td></tr><tr><td>.mx</td><td>1111</td></tr><tr><td>.bm</td><td>1240</td></tr><tr><td>.lu</td><td>1392</td></tr><tr><td>.ie</td><td>1802</td></tr><tr><td>.kr</td><td>1862</td></tr><tr><td>.hu</td><td>1980</td></tr><tr><td>.nz</td><td>2014</td></tr><tr><td>.dk</td><td>2264</td></tr><tr><td>.sk</td><td>2329</td></tr><tr><td>.mt</td><td>2955</