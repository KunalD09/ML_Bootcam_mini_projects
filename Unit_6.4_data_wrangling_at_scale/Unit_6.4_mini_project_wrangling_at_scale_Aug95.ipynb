# %% [markdown]
# ## Overview
#
# This notebook will show you how to create and query a table or DataFrame that you uploaded to DBFS. [DBFS](https://docs.databricks.com/user-guide/dbfs-databricks-file-system.html) is a Databricks File System that allows you to store data for querying inside of Databricks. This notebook assumes that you have a file already inside of DBFS that you would like to read from.
#
# This notebook is written in **Python** so the default cell type is Python. However, you can use different languages by using the `%LANGUAGE` syntax. Python, Scala, SQL, and R are all supported.

# %%
import glob
import os 
import pandas as pd
from pyspark.sql.functions import split
import re
import numpy as np
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# File location and type
file_location = "/FileStore/tables/NASA_access_log_Aug95-1.gz"
my_list = []
# The applied options are for CSV files. For other file types, these will be ignored.
df = spark.read.csv(file_location, sep=' ')
#df = df.select(split(df._c5, ' ').alias(['type','a1','a2'])).collect()
my_list = df.select('_c5').rdd.flatMap(lambda x: x).collect()
my_list2 = df.select('_c0').rdd.flatMap(lambda x: x).collect()
my_list3 = df.select('_c7').rdd.flatMap(lambda x: x).collect()
my_list4 = df.select('_c3').rdd.flatMap(lambda x: x).collect()
my_list5 = df.select('_c4').rdd.flatMap(lambda x: x).collect()
my_list6 = df.select('_c6').rdd.flatMap(lambda x: x).collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(df.tail(1000))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>_c0</th><th>_c1</th><th>_c2</th><th>_c3</th><th>_c4</th><th>_c5</th><th>_c6</th><th>_c7</th></tr></thead><tbody><tr><td>kabuto.phys.wani.osaka-u.ac.jp</td><td>-</td><td>-</td><td>[31/Aug/1995:23:32:34</td><td>-0400]</td><td>GET /shuttle/missions/sts-70/images/KSC-95EC-1019.jpg HTTP/1.0</td><td>200</td><td>69005</td></tr><tr><td>c30.eds.ecip.nagoya-u.ac.jp</td><td>-</td><td>-</td><td>[31/Aug/1995:23:32:34</td><td>-0400]</td><td>GET /facilities/mlp.html HTTP/1.0</td><td>200</td><td>2653</td></tr><tr><td>c30.eds.ecip.nagoya-u.ac.jp</td><td>-</td><td>-</td><td>[31/Aug/1995:23:32:37</td><td>-0400]</td><td>GET /images/mlp-logo.gif HTTP/1.0</td><td>200</td><td>28426</td></tr><tr><td>198.211.77.73</td><td>-</td><td>-</td><td>[31/Aug/1995:23:32:38</td><td>-0400]</td><td>GET /shuttle/missions/61-c/61-c-patch-small.gif HTTP/1.0</td><td>200</td><td>11963</td></tr><tr><td>157.2.11.70</td><td>-</td><td>-</td><td>[31/Aug/1995:23:32:41</td><td>-0400]</td><td>GET /images/launchmedium.gif HTTP/1.0</td><td>200</td><td>11853</td></tr><tr><td>c30.eds.ecip.nagoya-u.ac.jp</td><td>-</td><td>-</td><td>[31/Aug/1995:23:32:42</td><td>-0400]</td><td>GET /images/kscmap-tiny.gif HTTP/1.0</td><td>200</td><td>2537</td></tr><tr><td>ix-dgr-il1-12.ix.netcom.com</td><td>-</td><td>-</td><td>[31/Aug/1995:23:32:44</td><td>-0400]</td><td>GET /shuttle/missions/sts-69/images/KSC-95EC-1244.jpg HTTP/1.0</td><td>200</td><td>136166</td></tr><tr><td>157.2.11.70</td><td>-</td><td>-</td><td>[31/Aug/1995:23:32:46</td><td>-0400]</td><td>GET /images/NASA-logosmall.gif HTTP/1.0</td><td>200</td><td>786</td></tr><tr><td>198.211.77.73</td><td>-</td><td>-</td><td>[31/Aug/1995:23:32:50</td><td>-0400]</td><td>GET /shuttle/missions/51-c/mission-51-c.html HTTP/1.0</td><td>200</td><td>4556</td></tr><tr><td>198.211.77.73</td><td>-</td><td>-</td><td>[31/Aug/1995:23:32:51</td><td>-0400]</td><td>GET /shuttle/missions/51-c/51-c-patch-small.gif HTTP/1.0</td><td>200</td><td>12632</td></tr><tr><td>c30.eds.ecip.nagoya-u.ac.jp</td><td>-</td><td>-</td><td>[31/Aug/1995:23:32:56</td><td>-0400]</td><td>GET /ksc.html HTTP/1.0</td><td>200</td><td>7089</td></tr><tr><td>feenix.slnsw.gov.au</td><td>-</td><td>-</td><td>[31/Aug/1995:23:33:01</td><td>-0400]</td><td>GET /htbin/wais.pl?flight+vectors HTTP/1.0</td><td>200</td><td>4202</td></tr><tr><td>tomdunc.interlog.com</td><td>-</td><td>-</td><td>[31/Aug/1995:23:33:08</td><td>-0400]</td><td>GET /shuttle/missions/sts-62/mission-sts-62.html HTTP/1.0</td><td>200</td><td>64658</td></tr><tr><td>204.185.50.65</td><td>-</td><td>-</td><td>[31/Aug/1995:23:33:15</td><td>-0400]</td><td>GET /shuttle/countdown/liftoff.html HTTP/1.0</td><td>200</td><td>7961</td></tr><tr><td>edams.ksc.nasa.gov</td><td>-</td><td>-</td><td>[31/Aug/1995:23:33:20</td><td>-0400]</td><td>GET /ksc.html HTTP/1.0</td><td>200</td><td>7089</td></tr><tr><td>apsicc.aps.edu</td><td>-</td><td>-</td><td>[31/Aug/1995:23:33:20</td><td>-0400]</td><td>GET /shuttle/countdown/ HTTP/1.0</td><td>200</td><td>4745</td></tr><tr><td>edams.ksc.nasa.gov</td><td>-</td><td>-</td><td>[31/Aug/1995:23:33:20</td><td>-0400]</td><td>GET /images/ksclogo-medium.gif HTTP/1.0</td><td>200</td><td>5866</td></tr><tr><td>edams.ksc.nasa.gov</td><td>-</td><td>-</td><td>[31/Aug/1995:23:33:21</td><td>-0400]</td><td>GET /images/NASA-logosmall.gif HTTP/1.0</td><td>200</td><td>786</td></tr><tr><td>jvidler.pcshs.com</td><td>-</td><td>-</td><td>[31/Aug/1995:23:33:21</td><td>-0400]</td><td>GET /facilities/lc39a.html HTTP/1.0</td><td>200</td><td>7008</td></tr><tr><td>edams.ksc.nasa.gov</td><td>-</td><td>-</td><td>[31/Aug/1995:23:33:21</td><td>-0400]</td><td>GET /images/MOSAIC-logosmall.gif HTTP/1.0</td><td>200</td><td>363</td></tr><tr><td>edams.ksc.nasa.gov</td><td>-</td><td>-</td><td>[31/Aug/1995:23:33:21</td><td>-0400]</td><td>GET /images/USA-logosmall.gif HTTP/1.0</td><td>200</td><td>234</td></tr><tr><td>edams.ksc.nasa.gov</td> ...

# %%
df_py = df[df['_c6']=='HTTP/1.0\"']
df_py.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------------+---+---+--------------------+------+--------------------+---------+---+
#                  _c0|_c1|_c2|                 _c3|   _c4|                 _c5|      _c6|_c7|
# +--------------------+---+---+--------------------+------+--------------------+---------+---+
#  userp2.snowhill.com|  -|  -|[05/Aug/1995:14:5...|-0400]|              GET / |HTTP/1.0&#34;|200|
# jhanley.doe.state...|  -|  -|[08/Aug/1995:11:2...|-0400]|       GET /ksc.html|HTTP/1.0&#34;|404|
# redx3.cac.washing...|  -|  -|[10/Aug/1995:18:4...|-0400]|GET /shuttle/miss...|HTTP/1.0&#34;|404|
# redx3.cac.washing...|  -|  -|[10/Aug/1995:18:4...|-0400]|GET /shuttle/miss...|HTTP/1.0&#34;|404|
#        128.95.234.46|  -|  -|[10/Aug/1995:19:2...|-0400]|GET /shuttle/miss...|HTTP/1.0&#34;|404|
# redx3.cac.washing...|  -|  -|[10/Aug/1995:20:0...|-0400]|GET /shuttle/miss...|HTTP/1.0&#34;|404|
# redx3.cac.washing...|  -|  -|[10/Aug/1995:20:0...|-0400]|GET /shuttle/miss...|HTTP/1.0&#34;|404|
# redx3.cac.washing...|  -|  -|[10/Aug/1995:20:0...|-0400]|GET /shuttle/miss...|HTTP/1.0&#34;|404|
# redx3.cac.washing...|  -|  -|[10/Aug/1995:20:0...|-0400]|GET /shuttle/miss...|HTTP/1.0&#34;|404|
# redx3.cac.washing...|  -|  -|[10/Aug/1995:20:0...|-0400]|GET /shuttle/miss...|HTTP/1.0&#34;|404|
# redx3.cac.washing...|  -|  -|[10/Aug/1995:20:0...|-0400]|GET /shuttle/miss...|HTTP/1.0&#34;|404|
# macba305.aerov.ju...|  -|  -|[22/Aug/1995:11:0...|-0400]|GET /shuttle/miss...|HTTP/1.0&#34;|404|
# macba305.aerov.ju...|  -|  -|[22/Aug/1995:11:0...|-0400]|GET /shuttle/miss...|HTTP/1.0&#34;|404|
# macba305.aerov.ju...|  -|  -|[22/Aug/1995:11:0...|-0400]|GET /shuttle/miss...|HTTP/1.0&#34;|404|
# piweba4y.prodigy.com|  -|  -|[27/Aug/1995:02:5...|-0400]|GET /shuttle/miss...|HTTP/1.0&#34;|404|
# piweba4y.prodigy.com|  -|  -|[27/Aug/1995:02:5...|-0400]|GET /shuttle/miss...|HTTP/1.0&#34;|404|
# groax1.gsfc.nasa.gov|  -|  -|[27/Aug/1995:18:5...|-0400]|GET /history/apol...|HTTP/1.0&#34;|404|
# +--------------------+---+---+--------------------+------+--------------------+---------+---+
#
# </div>

# %%
get_list = []
request_list1 = []
request_list2 = []
invalid = []
a = ''
b = ''
c = ''

for element in my_list: 
    #print('element = ',element)
    if element != None:
        get = element.split()
        #print('get = ',get)
        if len(get) >= 4:
            print('get = ',get)
            invalid.append(get)
        if len(get) == 3:
            a = get[0]
            b = get[1]
            c = get[2]
            get_list.append(a)
            request_list1.append(b)
            request_list2.append(c)
        elif len(get) == 2:
            a = get[0]
            b = get[1]
            c = 'NaN'
            get_list.append(a)
            request_list1.append(b)
            request_list2.append(c)
        elif len(get) == 1:
            match = re.match('\d',get[0])
            if match == None:
                a = get[0]
                b = 'NaN'
                c = 'NaN'
                get_list.append(a)
                request_list1.append(b)
                request_list2.append(c)
            else:
                a = 'NaN'
                b = get[0]
                c = 'NaN'
                get_list.append(a)
                request_list1.append(b)
                request_list2.append(c)
        else:
            a = 'NaN'
            b = 'NaN'
            c = 'NaN'
            get_list.append(a)
            request_list1.append(b)
            request_list2.append(c)
    else:
        a = 'NaN'
        b = 'NaN'
        c = 'NaN'
        get_list.append(a)
        request_list1.append(b)
        request_list2.append(c)
        
        

#print(get_list)
#print(request_list1)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">get =  [&#39;GET&#39;, &#39;/&#39;, &#39;/&#39;, &#39;HTTP/1.0&#39;]
# get =  [&#39;GET&#39;, &#39;/&#39;, &#39;/&#39;, &#39;HTTP/1.0&#39;]
# get =  [&#39;GET&#39;, &#39;/htbin/wais.pl?Wake&#39;, &#39;Shield&#39;, &#39;HTTP/1.0&#39;]
# get =  [&#39;GET&#39;, &#39;/shuttle/missions/sts-69/images/images.html&#39;, &#39;40,207&#39;, &#39;89,234&#39;, &#39;HTTP/1.0&#39;]
# get =  [&#39;GET&#39;, &#39;/shuttle/countdown/tour.html&#39;, &#39;40,243&#39;, &#39;89,262&#39;, &#39;HTTP/1.0&#39;]
# get =  [&#39;GET&#39;, &#39;/msfc/astro&#39;, &#39;home.html&#39;, &#39;HTTP/1.0&#39;]
# get =  [&#39;GET&#39;, &#39;/msfc/astro&#39;, &#39;home.html&#39;, &#39;HTTP/1.0&#39;]
# get =  [&#39;GET&#39;, &#39;/&#39;, &#39;/&#39;, &#39;HTTP/1.0&#39;]
# get =  [&#39;GET&#39;, &#39;/msfc/astro&#39;, &#39;home.html&#39;, &#39;HTTP/1.0&#39;]
# get =  [&#39;GET&#39;, &#39;/&#39;, &#39;history/apollo/apollo-13/apollo-13.html&#39;, &#39;HTTP/1.0&#39;]
# get =  [&#39;GET&#39;, &#39;/htbin/wais.pl?satellite&#39;, &#39;pictures&#39;, &#39;HTTP/1.0&#39;]
# get =  [&#39;GET&#39;, &#39;/&#39;, &#39;/&#39;, &#39;HTTP/1.0&#39;]
# get =  [&#39;GET&#39;, &#39;/robots.txt&#39;, &#39;HTML/1.0&#39;, &#39;headers&#39;]
# get =  [&#39;GET&#39;, &#39;/facilities/mila.html&gt;Merritt&#39;, &#39;Island&#39;, &#39;Spaceflight&#39;, &#39;Tracking&#39;, &#39;and&#39;, &#39;Data&#39;, &#39;Network&#39;, &#39;Station&#39;, &#39;(MILA)&lt;/a&gt;&#39;]
# get =  [&#39;GET&#39;, &#39;/history/apollo/apollo-13/apollo1-.html&#39;, &#39;apollo-1&#39;, &#39;HTTP/1.0&#39;]
# get =  [&#39;GET&#39;, &#39;/history/apollo/apollo-13/apollo1-.html&#39;, &#39;apollo-1&#39;, &#39;HTTP/1.0&#39;]
# get =  [&#39;GET&#39;, &#39;/history/apollo/apollo-13/apollo1-.html&#39;, &#39;apollo-1&#39;, &#39;HTTP/1.0&#39;]
# get =  [&#39;GET&#39;, &#39;/shuttle/technology/sts-newsref/http://www.ksc.nasa.gov/images/shuttle-patch-logo.gif&gt;&#39;, &#39;Table&#39;, &#39;of&#39;]
# get =  [&#39;GET&#39;, &#39;/shuttle/technology/sts-newsref/sts&#39;, &#39;egress.html&#39;, &#39;HTTP/1.0&#39;]
# get =  [&#39;GET&#39;, &#39;/shuttle/technology/sts-newsref/sts&#39;, &#39;egress.html&#39;, &#39;HTTP/1.0&#39;]
# get =  [&#39;GET&#39;, &#39;/shuttle/technology/sts-newsref/sts&#39;, &#39;egress.html&#39;, &#39;HTTP/1.0&#39;]
# get =  [&#39;GET&#39;, &#39;/shuttle/technology/sts-newsref/sts&#39;, &#39;egress.html&#39;, &#39;HTTP/1.0&#39;]
# get =  [&#39;GET&#39;, &#39;/shuttle/technology/sts-newsref/sts&#39;, &#39;egress.&#39;, &#39;HTTP/1.0&#39;]
# get =  [&#39;GET&#39;, &#39;/shuttle/technology/sts-newsref/sts&#39;, &#39;egress.&#39;, &#39;HTTP/1.0&#39;]
# get =  [&#39;GET&#39;, &#39;/shuttle/technology/sts-newsref/sts&#39;, &#39;egress.&#39;, &#39;HTTP/1.0&#39;]
# get =  [&#39;GET&#39;, &#39;/shuttle/technology/sts-newsref/sts&#39;, &#39;egress.html&#39;, &#39;HTTP/1.0&#39;]
# get =  [&#39;GET&#39;, &#39;/htbin/wais.pl?Spaceborne&#39;, &#39;Imaging&#39;, &#39;Radar-C&#39;, &#39;HTTP/1.0&#39;]
# get =  [&#39;GET&#39;, &#39;/htbin/wais.pl?Wake&#39;, &#39;Shield&#39;, &#39;HTTP/1.0&#39;]
# get =  [&#39;GET&#39;, &#39;/&#39;, &#39;history/apollo/apollo-13/apollo-13.html&#39;, &#39;HTTP/1.0&#39;]
# get =  [&#39;GET&#39;, &#39;/&#39;, &#39;history/apollo/apollo-13/history/history.html&#39;, &#39;HTTP/1.0&#39;]
# get =  [&#39;GET&#39;, &#39;/&#39;, &#39;history/apollo/apollo-13/history/history/history.html&#39;, &#39;HTTP/1.0&#39;]
# get =  [&#39;GET&#39;, &#39;/images/baseball&#39;, &#39;stadium&#39;, &#39;HTTP/1.0&#39;]
# get =  [&#39;GET&#39;, &#39;/&#39;, &#39;history/apollo/apollo-13/apollo-13.html&#39;, &#39;HTTP/1.0&#39;]
# get =  [&#39;GET&#39;, &#39;/htbin/wais.pl?OPM&#39;, &#39;job&#39;, &#39;HTTP/1.0&#39;]
# get =  [&#39;GET&#39;, &#39;/htbin/wais.pl?OPM&#39;, &#39;job&#39;, &#39;info&#39;, &#39;line&#39;, &#39;HTTP/1.0&#39;]
# get =  [&#39;GET&#39;, &#39;/ksc.html&gt;NASA&#39;, &#39;HOME&#39;, &#39;PAGE&lt;/a&gt;&lt;br&gt;&#39;, &#39;You&#39;, &#39;Gotta&#39;, &#39;Love&#39;, &#39;Those&#39;, &#39;Space&#39;, &#39;Ships&#39;]
# get =  [&#39;GET&#39;, &#39;/htbin/wais.pl?Wake&#39;, &#39;Shield&#39;, &#39;HTTP/1.0&#39;]
# get =  [&#39;GET&#39;, &#39;/images/NASA-logosmall.gif&#39;, &#39;align=left&#39;, &#39;HTTP/1.0&#39;]
# get =  [&#39;GET&#39;, &#39;/images/NASA-logosmall.gif&#39;, &#39;align=left&#39;, &#39;HTTP/1.0&#39;]
# get =  [&#39;GET&#39;, &#39;/htbin/wais.pl?space&#39;, &#39;photos&#39;, &#39;HTTP/1.0&#39;]
# get =  [&#39;GET&#39;, &#39;/software/winvn/winvn.htm&#39;, &#39;l&#39;, &#39;HTTP/1.0&#39;]
# get =  [&#39;GET&#39;, &#39;/shuttle/missions/sts-63/sts-63-press-kit.tx&#39;, &#39;t&#39;, &#39;HTTP/1.0&#39;]
# get =  [&#39;GET&#39;, &#39;/&#39;, &#39;l&#39;, &#39;HTTP/1.0&#39;]
# get =  [&#39;GET&#39;, &#39;/shuttle/missions/sts-70/movies/Hey&#39;, &#39;Beavis&#39;, &#39;HTTP/1.0&#39;]
# get =  [&#39;GET&#39;, &#39;/htbin/wais.pl?Spaceborne&#39;, &#39;Imaging&#39;, &#39;Radar-C&#39;, &#39;HTTP/1.0&#39;]
# get =  [&#39;GET&#39;, &#39;/ksc./launch&#39;, &#39;support/default.htm&#39;, &#39;HTTP/1.0&#39;]
# get =  [&#39;GET&#39;, &#39;/jsc/jsc_homepage&#39;, &#39;html&#39;, &#39;HTTP/1.0&#39;]
# get =  [&#39;GET&#39;, &#39;/htbin/wais.pl?Space&#39;, &#39;Acceleration&#39;, &#39;Measurement&#39;, &#39;System&#39;, &#39;HTTP/1.0&#39;]
# get =  [&#39;GET&#39;, &#39;/&#39;, &#39;/&#39;, &#39;HTTP/1.0&#39;]
# get =  [&#39;GET&#39;, &#39;/&#39;, &#39;/history/history.html&#39;, &#39;HTTP/1.0&#39;]
# get =  [&#39;GET&#39;, &#39;/&#39;, &#39;/history/history/history.html&#39;, &#39;HTTP/1.0&#39;]
# get =  [&#39;GET&#39;, &#39;/shuttle&#39;, &#39;mission//sts-69/mission-sts-69.html&#39;, &#39;HTTP/1.0&#39;]
# get =  [&#39;GET&#39;, &#39;/shuttle&#39;, &#39;mission/sts-73/mission-sts-73.html&#39;, &#39;HTTP/1.0&#39;]
# get =  [&#39;GET&#39;, &#39;/shuttle/countdown/dy&#39;, &#39;�?status%20report&#39;, &#39;HTTP/1.0&#39;]
# get =  [&#39;GET&#39;, &#39;/htbin/wais.pl?Spaceborne&#39;, &#39;Imaging&#39;, &#39;Radar-C&#39;, &#39;HTTP/1.0&#39;]
# get =  [&#39;GET&#39;, &#39;/shuttle/missions/sts-71/ruthless&#39;, &#39;g@aol.com&#39;, &#39;HTTP/1.0&#39;]
# get =  [&#39;GET&#39;, &#39;/shuttle/countdown&gt;&#39;, &#39;The&#39;, &#39;Shuttle&#39;, &#39;launch&#39;, &#39;countdown&#39;, &#39;homepage&lt;/a&gt;&lt;hr&gt;&#39;]
# get =  [&#39;GET&#39;, &#39;/&#39;, &#39;history/apollo/apollo-13/apollo-13.html&#39;, &#39;HTTP/1.0&#39;]
# get =  [&#39;GET&#39;, &#39;/shuttle/missions&#39;, &#39;/sts-75/mission-sts-75.html&#39;, &#39;HTTP/1.0&#39;]
# get =  [&#39;GET&#39;, &#39;/shuttle/missions&#39;, &#39;/sts-75/mission-sts-75.html&#39;, &#39;HTTP/1.0&#39;]
# get =  [&#39;GET&#39;, &#39;
# %%
# convert lists into pyspark dataframe

s1 = pd.Series(my_list2)
s2 = pd.Series(my_new_list)
s3 = pd.Series(my_list5)
s4 = pd.Series(get_list)
s5 = pd.Series(request_list1)
s6 = pd.Series(request_list2)
s7 = pd.Series(my_list6)
s8 = pd.Series(my_list3)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# # Pandas DataFrame formed using series

# %%
#new_df = pd.DataFrame(data = [s1,s2,s3], columns=['type','req1','req2'])
new_df = pd.DataFrame({'host': s1,'timestamp': s2, 'method': s4, 'endpoint': s5, 'protocol': s6,  'http_status': s7, 'content_size': s8})
print(new_df)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">                           host  ... content_size
# 0             in24.inetnebr.com  ...         1839
# 1               uplherc.upl.com  ...            0
# 2               uplherc.upl.com  ...            0
# 3               uplherc.upl.com  ...            0
# 4               uplherc.upl.com  ...            0
# ...                         ...  ...          ...
# 1569893     gatekeeper.uccu.com  ...            0
# 1569894     gatekeeper.uccu.com  ...            0
# 1569895   cys-cap-9.wyoming.com  ...        57344
# 1569896    www-c8.proxy.aol.com  ...          515
# 1569897  cindy.yamato.ibm.co.jp  ...        39017
#
# [1569898 rows x 7 columns]
# </div>

# %% [markdown]
# # Replacing the method type with the correct one

# %%
new_df['method'].replace(to_replace ="\"GET",
                 value ="GET", inplace=True)
#a_df = new_df[new_df['method'] == '"GET']
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
new_df['domain_name'] = new_df['host'].str.extract(r'(\.com|\.jp|\.net|\.gov|\.edu|\.ca|\.au|\.de|\.nz|\.uk|\.mil|\.sg|\.no|\.se|\.it|\.be|\.dk|\.org|\.ni|\.fr|\.fi|\.si|\.nl|\.arpa|\.ch|\.kr|\.za|\.su|\.at|\.lu|\.pl|\.il|\.es|\.cz|\.us|\.ar|\.mt|\.is|\.pt|\.my|\.ee|\.cl|\.gr|\.ie|\.mx|\.cr|\.br|\.ru|\.int|\.ve|\.cn|\.hu|\.gb|\.sk|\.pa|\.ge|\.bm)')
print(df_new.head(700))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">                     host                    timestamp  ... content_size domain_name
# 0       in24.inetnebr.com  [01/Aug/1995:00:00:01-0400]  ...         1839        .com
# 1         uplherc.upl.com  [01/Aug/1995:00:00:07-0400]  ...            0        .com
# 2         uplherc.upl.com  [01/Aug/1995:00:00:08-0400]  ...            0        .com
# 3         uplherc.upl.com  [01/Aug/1995:00:00:08-0400]  ...            0        .com
# 4         uplherc.upl.com  [01/Aug/1995:00:00:08-0400]  ...            0        .com
# ..                    ...                          ...  ...          ...         ...
# 695  piweba1y.prodigy.com  [01/Aug/1995:00:24:46-0400]  ...         1713        .com
# 696         133.43.106.47  [01/Aug/1995:00:24:50-0400]  ...          786         NaN
# 697         ras15.srv.net  [01/Aug/1995:00:24:57-0400]  ...         8677        .net
# 698         133.43.106.47  [01/Aug/1995:00:25:00-0400]  ...          363         NaN
# 699         ras15.srv.net  [01/Aug/1995:00:25:01-0400]  ...        11853        .net
#
# [700 rows x 8 columns]
# </div>

# %%
new_df['domain_name'].replace(to_replace =np.NaN,
                 value ="IP Address", inplace=True)

new_df
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[155]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>host</th>
#       <th>timestamp</th>
#       <th>method</th>
#       <th>endpoint</th>
#       <th>protocol</th>
#       <th>http_status</th>
#       <th>content_size</th>
#       <th>domain_name</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>in24.inetnebr.com</td>
#       <td>[01/Aug/1995:00:00:01-0400]</td>
#       <td>GET</td>
#       <td>/shuttle/missions/sts-68/news/sts-68-mcc-05.txt</td>
#       <td>HTTP/1.0</td>
#       <td>200</td>
#       <td>1839</td>
#       <td>.com</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>uplherc.upl.com</td>
#       <td>[01/Aug/1995:00:00:07-0400]</td>
#       <td>GET</td>
#       <td>/</td>
#       <td>HTTP/1.0</td>
#       <td>304</td>
#       <td>0</td>
#       <td>.com</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>uplherc.upl.com</td>
#       <td>[01/Aug/1995:00:00:08-0400]</td>
#       <td>GET</td>
#       <td>/images/ksclogo-medium.gif</td>
#       <td>HTTP/1.0</td>
#       <td>304</td>
#       <td>0</td>
#       <td>.com</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>uplherc.upl.com</td>
#       <td>[01/Aug/1995:00:00:08-0400]</td>
#       <td>GET</td>
#       <td>/images/MOSAIC-logosmall.gif</td>
#       <td>HTTP/1.0</td>
#       <td>304</td>
#       <td>0</td>
#       <td>.com</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>uplherc.upl.com</td>
#       <td>[01/Aug/1995:00:00:08-0400]</td>
#       <td>GET</td>
#       <td>/images/USA-logosmall.gif</td>
#       <td>HTTP/1.0</td>
#       <td>304</td>
#       <td>0</td>
#       <td>.com</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>1569893</th>
#       <td>gatekeeper.uccu.com</td>
#       <td>[31/Aug/1995:23:59:49-0400]</td>
#       <td>GET</td>
#       <td>/images/ksclogosmall.gif</td>
#       <td>HTTP/1.0</td>
#       <td>304</td>
#       <td>0</td>
#       <td>.com</td>
#     </tr>
#     <tr>
#       <th>1569894</th>
#       <td>gatekeeper.uccu.com</td>
#       <td>[31/Aug/1995:23:59:49-0400]</td>
#       <td>GET</td>
#       <td>/images/lc39a-logo.gif</td>
#       <td>HTTP/1.0</td>
#       <td>304</td>
#       <td>0</td>
#       <td>.com</td>
#     </tr>
#     <tr>
#       <th>1569895</th>
#       <td>cys-cap-9.wyoming.com</td>
#       <td>[31/Aug/1995:23:59:52-0400]</td>
#       <td>GET</td>
#       <td>/shuttle/missions/sts-71/movies/sts-71-launch-...</td>
#       <td>HTTP/1.0</td>
#       <td>200</td>
#       <td>57344</td>
#       <td>.com</td>
#     </tr>
#     <tr>
#       <th>1569896</th>
#       <td>www-c8.proxy.aol.com</td>
#       <td>[31/Aug/1995:23:59:52-0400]</td>
#       <td>GET</td>
#       <td>/icons/unknown.xbm</td>
#       <td>HTTP/1.0</td>
#       <td>200</td>
#       <td>515</td>
#       <td>.com</td>
#     </tr>
#     <tr>
#       <th>1569897</th>
#       <td>cindy.yamato.ibm.co.jp</td>
#       <td>[31/Aug/1995:23:59:53-0400]</td>
#       <td>GET</td>
#       <td>/images/kscmap-small.gif</td>
#       <td>HTTP/1.0</td>
#       <td>200</td>
#       <td>39017</td>
#       <td>.jp</td>
#     </tr>
#   </tbody>
# </table>
# <p>1569898 rows × 8 columns</p>
# </div>

# %% [markdown]
# # Created the PySpark DataFrame

# %%
spark_df = spark.createDataFrame(new_df)
display(spark_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>host</th><th>timestamp</th><th>method</th><th>endpoint</th><th>protocol</th><th>http_status</th><th>content_size</th><th>domain_name</th></tr></thead><tbody><tr><td>in24.inetnebr.com</td><td>[01/Aug/1995:00:00:01-0400]</td><td>GET</td><td>/shuttle/missions/sts-68/news/sts-68-mcc-05.txt</td><td>HTTP/1.0</td><td>200</td><td>1839</td><td>.com</td></tr><tr><td>uplherc.upl.com</td><td>[01/Aug/1995:00:00:07-0400]</td><td>GET</td><td>/</td><td>HTTP/1.0</td><td>304</td><td>0</td><td>.com</td></tr><tr><td>uplherc.upl.com</td><td>[01/Aug/1995:00:00:08-0400]</td><td>GET</td><td>/images/ksclogo-medium.gif</td><td>HTTP/1.0</td><td>304</td><td>0</td><td>.com</td></tr><tr><td>uplherc.upl.com</td><td>[01/Aug/1995:00:00:08-0400]</td><td>GET</td><td>/images/MOSAIC-logosmall.gif</td><td>HTTP/1.0</td><td>304</td><td>0</td><td>.com</td></tr><tr><td>uplherc.upl.com</td><td>[01/Aug/1995:00:00:08-0400]</td><td>GET</td><td>/images/USA-logosmall.gif</td><td>HTTP/1.0</td><td>304</td><td>0</td><td>.com</td></tr><tr><td>ix-esc-ca2-07.ix.netcom.com</td><td>[01/Aug/1995:00:00:09-0400]</td><td>GET</td><td>/images/launch-logo.gif</td><td>HTTP/1.0</td><td>200</td><td>1713</td><td>.net</td></tr><tr><td>uplherc.upl.com</td><td>[01/Aug/1995:00:00:10-0400]</td><td>GET</td><td>/images/WORLD-logosmall.gif</td><td>HTTP/1.0</td><td>304</td><td>0</td><td>.com</td></tr><tr><td>slppp6.intermind.net</td><td>[01/Aug/1995:00:00:10-0400]</td><td>GET</td><td>/history/skylab/skylab.html</td><td>HTTP/1.0</td><td>200</td><td>1687</td><td>.int</td></tr><tr><td>piweba4y.prodigy.com</td><td>[01/Aug/1995:00:00:10-0400]</td><td>GET</td><td>/images/launchmedium.gif</td><td>HTTP/1.0</td><td>200</td><td>11853</td><td>.com</td></tr><tr><td>slppp6.intermind.net</td><td>[01/Aug/1995:00:00:11-0400]</td><td>GET</td><td>/history/skylab/skylab-small.gif</td><td>HTTP/1.0</td><td>200</td><td>9202</td><td>.int</td></tr><tr><td>slppp6.intermind.net</td><td>[01/Aug/1995:00:00:12-0400]</td><td>GET</td><td>/images/ksclogosmall.gif</td><td>HTTP/1.0</td><td>200</td><td>3635</td><td>.int</td></tr><tr><td>ix-esc-ca2-07.ix.netcom.com</td><td>[01/Aug/1995:00:00:12-0400]</td><td>GET</td><td>/history/apollo/images/apollo-logo1.gif</td><td>HTTP/1.0</td><td>200</td><td>1173</td><td>.net</td></tr><tr><td>slppp6.intermind.net</td><td>[01/Aug/1995:00:00:13-0400]</td><td>GET</td><td>/history/apollo/images/apollo-logo.gif</td><td>HTTP/1.0</td><td>200</td><td>3047</td><td>.int</td></tr><tr><td>uplherc.upl.com</td><td>[01/Aug/1995:00:00:14-0400]</td><td>GET</td><td>/images/NASA-logosmall.gif</td><td>HTTP/1.0</td><td>304</td><td>0</td><td>.com</td></tr><tr><td>133.43.96.45</td><td>[01/Aug/1995:00:00:16-0400]</td><td>GET</td><td>/shuttle/missions/sts-69/mission-sts-69.html</td><td>HTTP/1.0</td><td>200</td><td>10566</td><td>IP Address</td></tr><tr><td>kgtyk4.kj.yamagata-u.ac.jp</td><td>[01/Aug/1995:00:00:17-0400]</td><td>GET</td><td>/</td><td>HTTP/1.0</td><td>200</td><td>7280</td><td>.jp</td></tr><tr><td>kgtyk4.kj.yamagata-u.ac.jp</td><td>[01/Aug/1995:00:00:18-0400]</td><td>GET</td><td>/images/ksclogo-medium.gif</td><td>HTTP/1.0</td><td>200</td><td>5866</td><td>.jp</td></tr><tr><td>d0ucr6.fnal.gov</td><td>[01/Aug/1995:00:00:19-0400]</td><td>GET</td><td>/history/apollo/apollo-16/apollo-16.html</td><td>HTTP/1.0</td><td>200</td><td>2743</td><td>.gov</td></tr><tr><td>ix-esc-ca2-07.ix.netcom.com</td><td>[01/Aug/1995:00:00:19-0400]</td><td>GET</td><td>/shuttle/resources/orbiters/discovery.html</td><td>HTTP/1.0</td><td>200</td><td>6849</td><td>.net</td></tr><tr><td>d0ucr6.fnal.gov</td><td>[01/Aug/1995:00:00:20-0400]</td><td>GET</td><td>/history/apollo/apollo-16/apollo-16-patch-small.gif</td><td>HTTP/1.0</td><td>200</td><td>14897</td><td>.gov</td></tr><tr><td>kgtyk4.kj.yamagata-u.ac.jp</td><td>[01/Aug/1995:00:00:21-0400]</td><td>GET</td><td>/images/NASA-logosmall.gif</td><td>HTTP/1.0</td><td>304</td><td>0</td>< ...

# %% [markdown]
# # Named the PySpark DataFrame to be used in SQL

# %%
spark_df.registerTempTable("df_final")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
sqldf1 = spark.sql("SELECT host, timestamp, method, endpoint, protocol, http_status, content_size, domain_name FROM df_final WHERE http_status = 'HTTP/1.0\"'")
sqldf1.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------------+--------------------+------+--------------------+--------+-----------+------------+-----------+
#                 host|           timestamp|method|            endpoint|protocol|http_status|content_size|domain_name|
# +--------------------+--------------------+------+--------------------+--------+-----------+------------+-----------+
#  userp2.snowhill.com|[05/Aug/1995:14:5...|   GET|                   /|     NaN|  HTTP/1.0&#34;|         200|       .com|
# jhanley.doe.state...|[08/Aug/1995:11:2...|   GET|           /ksc.html|     NaN|  HTTP/1.0&#34;|         404|        .us|
# redx3.cac.washing...|[10/Aug/1995:18:4...|   GET|/shuttle/missions...|     NaN|  HTTP/1.0&#34;|         404|        .ca|
# redx3.cac.washing...|[10/Aug/1995:18:4...|   GET|/shuttle/missions...|     NaN|  HTTP/1.0&#34;|         404|        .ca|
#        128.95.234.46|[10/Aug/1995:19:2...|   GET|/shuttle/missions...|     NaN|  HTTP/1.0&#34;|         404| IP Address|
# redx3.cac.washing...|[10/Aug/1995:20:0...|   GET|/shuttle/missions...|     NaN|  HTTP/1.0&#34;|         404|        .ca|
# redx3.cac.washing...|[10/Aug/1995:20:0...|   GET|/shuttle/missions...|     NaN|  HTTP/1.0&#34;|         404|        .ca|
# redx3.cac.washing...|[10/Aug/1995:20:0...|   GET|/shuttle/missions...|     NaN|  HTTP/1.0&#34;|         404|        .ca|
# redx3.cac.washing...|[10/Aug/1995:20:0...|   GET|/shuttle/missions...|     NaN|  HTTP/1.0&#34;|         404|        .ca|
# redx3.cac.washing...|[10/Aug/1995:20:0...|   GET|/shuttle/missions...|     NaN|  HTTP/1.0&#34;|         404|        .ca|
# redx3.cac.washing...|[10/Aug/1995:20:0...|   GET|/shuttle/missions...|     NaN|  HTTP/1.0&#34;|         404|        .ca|
# macba305.aerov.ju...|[22/Aug/1995:11:0...|   GET|/shuttle/missions...|     NaN|  HTTP/1.0&#34;|         404|        .fr|
# macba305.aerov.ju...|[22/Aug/1995:11:0...|   GET|/shuttle/missions...|     NaN|  HTTP/1.0&#34;|         404|        .fr|
# macba305.aerov.ju...|[22/Aug/1995:11:0...|   GET|/shuttle/missions...|     NaN|  HTTP/1.0&#34;|         404|        .fr|
# piweba4y.prodigy.com|[27/Aug/1995:02:5...|   GET|/shuttle/missions...|     NaN|  HTTP/1.0&#34;|         404|       .com|
# piweba4y.prodigy.com|[27/Aug/1995:02:5...|   GET|/shuttle/missions...|     NaN|  HTTP/1.0&#34;|         404|       .com|
# groax1.gsfc.nasa.gov|[27/Aug/1995:18:5...|   GET|/history/apollo/a...|     NaN|  HTTP/1.0&#34;|         404|       .gov|
# +--------------------+--------------------+------+--------------------+--------+-----------+------------+-----------+
#
# </div>

# %% [markdown]
# # SQL used to create a table

# %%
# %sql
SELECT *
FROM df_final
--WHERE (method != 'GET') and (method != 'HEAD') and (method != 'POST')
GROUP BY host, timestamp, method, endpoint, protocol, http_status, content_size, domain_name
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>host</th><th>timestamp</th><th>method</th><th>endpoint</th><th>protocol</th><th>http_status</th><th>content_size</th><th>domain_name</th></tr></thead><tbody><tr><td>kgtyk4.kj.yamagata-u.ac.jp</td><td>[01/Aug/1995:00:00
td></tr><tr><td>uplherc.upl.com</td><td>[01/Aug/1995:00:14:38-0400]</td><td>GET</td><td>/images/shuttle-patch-small.gif</td><td>HTTP/1.0</td><td>200</td><td>4179</td><td>.com</td></tr><tr><td>haraway.ucet.ufl.edu</td><td>[01/Aug/1995:00:01:43-0400]</td><td>GET</td><td>/images/lc39a-logo.gif</td><td>HTTP/1.0</td><td>200</td><td>13116</td><td>.edu</td></tr><tr><td>dialip129.gov.bc.ca</td><td>[01/Aug/1995:00:32:42-0400]</td><td>GET</td><td>/history/apollo/apollo-12/movies/</td><td>HTTP/1.0</td><td>200</td><td>381</td><td>.gov</td></tr><tr><td>bdmgate.bdm.com</td><td>[01/Aug/1995:00:36:17-0400]</td><td>GET</td><td>/images/launchmedium.gif</td><td>HTTP/1.0</td><td>200</td><td>1 ...

# %% [markdown]
# # SQL used to count the number of http methods

# %%
# %sql
SELECT method, COUNT(method) 
FROM df_final
GROUP BY method
ORDER BY method
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>method</th><th>count(method)</th></tr></thead><tbody><tr><td>��6��T7�F��F</td><td>4</td></tr><tr><td>?</td><td>1</td></tr><tr><td>GET</td><td>1565095</td></tr><tr><td>HEAD</td><td>3965</td></tr><tr><td>NaN</td><td>717</td></tr><tr><td>POST</td><td>111</td></tr><tr><td>huttle/countdown/</td><td>1</td></tr><tr><td>�|t�9ð'À|u</td><td>2</td></tr><tr><td>���.�</td><td>2</td></tr></tbody></table></div>

# %%
# %sql
SELECT *
FROM df_final
WHERE (method != 'GET') and (method != 'POST') and (method != 'HEAD')
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>host</th><th>timestamp</th><th>method</th><th>endpoint</th><th>protocol</th><th>http_status</th><th>content_size</th><th>domain_name</th></tr></thead><tbody><tr><td>ztm-13.dial.xs4all.nl</td><td>[04/Aug/1995:09:34:52-0400]</td><td>NaN</td><td>NaN</td><td>NaN</td><td>200</td><td>7034</td><td>.nl</td></tr><tr><td>pc32.cis.uoguelph.ca</td><td>[04/Aug/1995:10:57:21-0400]</td><td>NaN</td><td>NaN</td><td>NaN</td><td>200</td><td>7034</td><td>.ca</td></tr><tr><td>sgate08.st-and.ac.uk</td><td>[04/Aug/1995:17:52:59-0400]</td><td>NaN</td><td>NaN</td><td>NaN</td><td>200</td><td>6858</td><td>.uk</td></tr><tr><td>ppp-nyc-2-64.ios.com</td><td>[05/Aug/1995:20:45:33-0400]</td><td>NaN</td><td>NaN</td><td>NaN</td><td>200</td><td>2443</td><td>.com</td></tr><tr><td>ppp-nyc-2-64.ios.com</td><td>[05/Aug/1995:20:47:52-0400]</td><td>NaN</td><td>NaN</td><td>NaN</td><td>200</td><td>4347</td><td>.com</td></tr><tr><td>client-71-162.online.apple.com</td><td>[05/Aug/1995:22:53:19-0400]</td><td>NaN</td><td>NaN</td><td>NaN</td><td>404</td><td>-</td><td>.com</td></tr><tr><td>client-71-162.online.apple.com</td><td>[05/Aug/1995:22:53:47-0400]</td><td>NaN</td><td>NaN</td><td>NaN</td><td>404</td><td>-</td><td>.com</td></tr><tr><td>rt99-9.rotterdam.nl.net</td><td>[06/Aug/1995:11:35:40-0400]</td><td>NaN</td><td>NaN</td><td>NaN</td><td>200</td><td>7034</td><td>.nl</td></tr><tr><td>client-71-69.online.apple.com</td><td>[06/Aug/1995:12:21:18-0400]</td><td>NaN</td><td>NaN</td><td>NaN</td><td>404</td><td>-</td><td>.com</td></tr><tr><td>spark1.ecf.toronto.edu</td><td>[06/Aug/1995:16:13:52-0400]</td><td>NaN</td><td>NaN</td><td>NaN</td><td>200</td><td>7034</td><td>.edu</td></tr><tr><td>bos49.pi.net</td><td>[06/Aug/1995:16:31:40-0400]</td><td>NaN</td><td>NaN</td><td>NaN</td><td>200</td><td>321</td><td>.net</td></tr><tr><td>194.151.8.5</td><td>[07/Aug/1995:08:48:56-0400]</td><td>NaN</td><td>NaN</td><td>NaN</td><td>200</td><td>7034</td><td>IP Address</td></tr><tr><td>www.db.erau.edu</td><td>[07/Aug/1995:11:19:10-0400]</td><td>NaN</td><td>NaN</td><td>NaN</td><td>404</td><td>-</td><td>.edu</td></tr><tr><td>pc532-03.gsfc.nasa.gov</td><td>[07/Aug/1995:12:40:13-0400]</td><td>NaN</td><td>NaN</td><td>NaN</td><td>404</td><td>-</td><td>.gov</td></tr><tr><td>ara2.acs.muohio.edu</td><td>[07/Aug/1995:20:40:00-0400]</td><td>NaN</td><td>NaN</td><td>NaN</td><td>404</td><td>-</td><td>.edu</td></tr><tr><td>ara2.acs.muohio.edu</td><td>[07/Aug/1995:20:41:10-0400]</td><td>NaN</td><td>NaN</td><td>NaN</td><td>404</td><td>-</td><td>.edu</td></tr><tr><td>ara2.acs.muohio.edu</td><td>[07/Aug/1995:20:41:18-0400]</td><td>NaN</td><td>NaN</td><td>NaN</td><td>404</td><td>-</td><td>.edu</td></tr><tr><td>hyperweb.mit.edu</td><td>[08/Aug/1995:09:01:06-0400]</td><td>NaN</td><td>NaN</td><td>NaN</td><td>404</td><td>-</td><td>.edu</td></tr><tr><td>193.62.104.204</td><td>[08/Aug/1995:09:38:29-0400]</td><td>NaN</td><td>NaN</td><td>NaN</td><td>404</td><td>-</td><td>IP Address</td></tr><tr><td>193.62.104.204</td><td>[08/Aug/1995:09:38:47-0400]</td><td>NaN</td><td>NaN</td><td>NaN</td><td>404</td><td>-</td><td>IP Address</td></tr><tr><td>193.62.104.204</td><td>[08/Aug/1995:09:39:00-0400]</td><td>NaN</td><td>NaN</td><td>NaN</td><td>404</td><td>-</td><td>IP Address</td></tr><tr><td>193.62.104.204</td><td>[08/Aug/1995:09:39:36-0400]</td><td>NaN</td><td>NaN</td><td>NaN</td><td>404</td><td>-</td><td>IP Address</td></tr><tr><td>193.62.104.204</td><td>[08/Aug/1995:09:40:07-0400]</td><td>NaN</td><td>NaN</td><td>NaN</td><td>404</td><td>-</td><td>IP Address</td></tr><tr><td>193.62.104.204</td><td>[08/Aug/1995:09:40:26-0400]</td><td>NaN</td><td>NaN</td><td>NaN</td><td>404</td><td>-</td><td>IP Address</td></tr><tr><td>193.62.104.204</td><td>[08/Aug/1995:09:42:20-0400]</td><td>NaN</td><td>NaN</td><td>NaN</td><td>404</td><td>-</td><td>IP Address</td></tr><tr><td>193.62.104.204</td><td>[08/Aug/1995:09:42:27-0400]</td> ...

# %% [markdown]
# # count number of methods for invalid endpoints - '/'

# %%
# %sql
SELECT method, endpoint, COUNT(endpoint)
FROM df_final
WHERE endpoint = '/' and (method = 'GET' or method = 'POST')
GROUP BY method, endpoint
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>method</th><th>endpoint</th><th>count(endpoint)</th></tr></thead><tbody><tr><td>GET</td><td>/</td><td>30101</td></tr></tbody></table></div>

# %% [markdown]
# # Identify the HTTP status and assign response

# %%
# %sql
--SELECT OrderID, Quantity,
--CASE
--    WHEN Quantity > 30 THEN 'The quantity is greater than 30'
--    WHEN Quantity = 30 THEN 'The quantity is 30'
--    ELSE 'The quantity is under 30'
--END AS QuantityText
--FROM OrderDetails;

SELECT http_status, COUNT(http_status) as number_of_http_status, 
CASE 
            WHEN http_status = '200' THEN 'OK'
            WHEN http_status = '302' THEN 'FOUND'
            WHEN http_status = '304' THEN 'NOT MODIFIED'
            WHEN http_status = '400' THEN 'BAD REQUEST'
            WHEN http_status = '403' THEN 'FORBIDDEN'
            WHEN http_status = '404' THEN 'NOT FOUND'
            WHEN http_status = '500' THEN 'INTERNAL SERVICE ERROR'
            WHEN http_status = '501' THEN 'NOT IMPLEMENTED'
            WHEN http_status = 'HTTP/1.0\"' THEN 'FORBIDDEN or INVALID'
            WHEN http_status = 'of'  THEN 'INVALID'
END as HTTP_RESPONSE
FROM df_final
GROUP BY http_status
ORDER BY http_status
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>http_status</th><th>number_of_http_status</th><th>HTTP_RESPONSE</th></tr></thead><tbody><tr><td>200</td><td>1398987</td><td>OK</td></tr><tr><td>302</td><td>26497</td><td>FOUND</td></tr><tr><td>304</td><td>134146</td><td>NOT MODIFIED</td></tr><tr><td>400</td><td>10</td><td>BAD REQUEST</td></tr><tr><td>403</td><td>171</td><td>FORBIDDEN</td></tr><tr><td>404</td><td>10039</td><td>NOT FOUND</td></tr><tr><td>500</td><td>3</td><td>INTERNAL SERVICE ERROR</td></tr><tr><td>501</td><td>27</td><td>NOT IMPLEMENTED</td></tr><tr><td>HTTP/1.0"</td><td>17</td><td>FORBIDDEN or INVALID</td></tr><tr><td>images/ssbuv1.gif</td><td>1</td><td>null</td></tr></tbody></table></div>

# %% [markdown]
# # Extract the http requests that has content size 0 or NULL

# %%
# %sql
SELECT *
FROM df_final
WHERE (content_size = '0') or (content_size is NULL)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>host</th><th>timestamp</th><th>method</th><th>endpoint</th><th>protocol</th><th>http_status</th><th>content_size</th><th>domain_name</th></tr></thead><tbody><tr><td>uplherc.upl.com</td><td>[01/Aug/1995:00:00:07-0400]</td><td>GET</td><td>/</td><td>HTTP/1.0</td><td>304</td><td>0</td><td>.com</td></tr><tr><td>uplherc.upl.com</td><td>[01/Aug/1995:00:00:08-0400]</td><td>GET</td><td>/images/ksclogo-medium.gif</td><td>HTTP/1.0</td><td>304</td><td>0</td><td>.com</td></tr><tr><td>uplherc.upl.com</td><td>[01/Aug/1995:00:00:08-0400]</td><td>GET</td><td>/images/MOSAIC-logosmall.gif</td><td>HTTP/1.0</td><td>304</td><td>0</td><td>.com</td></tr><tr><td>uplherc.upl.com</td><td>[01/Aug/1995:00:00:08-0400]</td><td>GET</td><td>/images/USA-logosmall.gif</td><td>HTTP/1.0</td><td>304</td><td>0</td><td>.com</td></tr><tr><td>uplherc.upl.com</td><td>[01/Aug/1995:00:00:10-0400]</td><td>GET</td><td>/images/WORLD-logosmall.gif</td><td>HTTP/1.0</td><td>304</td><td>0</td><td>.com</td></tr><tr><td>uplherc.upl.com</td><td>[01/Aug/1995:00:00:14-0400]</td><td>GET</td><td>/images/NASA-logosmall.gif</td><td>HTTP/1.0</td><td>304</td><td>0</td><td>.com</td></tr><tr><td>kgtyk4.kj.yamagata-u.ac.jp</td><td>[01/Aug/1995:00:00:21-0400]</td><td>GET</td><td>/images/NASA-logosmall.gif</td><td>HTTP/1.0</td><td>304</td><td>0</td><td>.jp</td></tr><tr><td>kgtyk4.kj.yamagata-u.ac.jp</td><td>[01/Aug/1995:00:00:21-0400]</td><td>GET</td><td>/images/MOSAIC-logosmall.gif</td><td>HTTP/1.0</td><td>304</td><td>0</td><td>.jp</td></tr><tr><td>kgtyk4.kj.yamagata-u.ac.jp</td><td>[01/Aug/1995:00:00:22-0400]</td><td>GET</td><td>/images/USA-logosmall.gif</td><td>HTTP/1.0</td><td>304</td><td>0</td><td>.jp</td></tr><tr><td>kgtyk4.kj.yamagata-u.ac.jp</td><td>[01/Aug/1995:00:00:22-0400]</td><td>GET</td><td>/images/WORLD-logosmall.gif</td><td>HTTP/1.0</td><td>304</td><td>0</td><td>.jp</td></tr><tr><td>205.163.36.61</td><td>[01/Aug/1995:00:01:57-0400]</td><td>GET</td><td>/shuttle/countdown/count70.gif</td><td>HTTP/1.0</td><td>304</td><td>0</td><td>IP Address</td></tr><tr><td>205.163.36.61</td><td>[01/Aug/1995:00:02:01-0400]</td><td>GET</td><td>/images/NASA-logosmall.gif</td><td>HTTP/1.0</td><td>304</td><td>0</td><td>IP Address</td></tr><tr><td>205.163.36.61</td><td>[01/Aug/1995:00:02:01-0400]</td><td>GET</td><td>/images/KSC-logosmall.gif</td><td>HTTP/1.0</td><td>304</td><td>0</td><td>IP Address</td></tr><tr><td>rpgopher.aist.go.jp</td><td>[01/Aug/1995:00:02:02-0400]</td><td>GET</td><td>/images/NASA-logosmall.gif</td><td>HTTP/1.0</td><td>304</td><td>0</td><td>.jp</td></tr><tr><td>rpgopher.aist.go.jp</td><td>[01/Aug/1995:00:02:04-0400]</td><td>GET</td><td>/images/USA-logosmall.gif</td><td>HTTP/1.0</td><td>304</td><td>0</td><td>.jp</td></tr><tr><td>rpgopher.aist.go.jp</td><td>[01/Aug/1995:00:02:04-0400]</td><td>GET</td><td>/images/ksclogo-medium.gif</td><td>HTTP/1.0</td><td>304</td><td>0</td><td>.jp</td></tr><tr><td>rpgopher.aist.go.jp</td><td>[01/Aug/1995:00:02:04-0400]</td><td>GET</td><td>/images/MOSAIC-logosmall.gif</td><td>HTTP/1.0</td><td>304</td><td>0</td><td>.jp</td></tr><tr><td>rpgopher.aist.go.jp</td><td>[01/Aug/1995:00:02:05-0400]</td><td>GET</td><td>/images/WORLD-logosmall.gif</td><td>HTTP/1.0</td><td>304</td><td>0</td><td>.jp</td></tr><tr><td>205.163.36.61</td><td>[01/Aug/1995:00:02:15-0400]</td><td>GET</td><td>/shuttle/countdown/liftoff.html</td><td>HTTP/1.0</td><td>304</td><td>0</td><td>IP Address</td></tr><tr><td>rpgopher.aist.go.jp</td><td>[01/Aug/1995:00:02:30-0400]</td><td>GET</td><td>/shuttle/countdown/count70.gif</td><td>HTTP/1.0</td><td>304</td><td>0</td><td>.jp</td></tr><tr><td>rpgopher.aist.go.jp</td><td>[01/Aug/1995:00:02:30-0400]</td><td>GET</td><td>/images/KSC-logosmall.gif</td><td>HTTP/1.0</td><td>304</td><td>0</td><td>.jp</td></tr><tr><td>rpgopher.aist.go.jp</td><td>[01/Aug/1995:00:02:50-0400]</td><td>GET</td><td>/shuttle/missions/sts-70/sts-70-patch-small ...

# %% [markdown]
# # Extract the number of methods that has content = 0 or content = 'null'

# %%
# %sql 
SELECT method, COUNT(method) as number_of_methods, http_status, content_size
FROM df_final
WHERE (content_size = '0') or (content_size is NULL)
GROUP BY method, http_status, content_size
ORDER BY method, http_status
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>method</th><th>number_of_methods</th><th>http_status</th><th>content_size</th></tr></thead><tbody><tr><td>GET</td><td>2287</td><td>200</td><td>0</td></tr><tr><td>GET</td><td>15</td><td>302</td><td>0</td></tr><tr><td>GET</td><td>134138</td><td>304</td><td>0</td></tr><tr><td>HEAD</td><td>3959</td><td>200</td><td>0</td></tr><tr><td>HEAD</td><td>3</td><td>302</td><td>0</td></tr><tr><td>NaN</td><td>8</td><td>304</td><td>0</td></tr></tbody></table></div>

# %%
# %sql 
SELECT method, COUNT(method) as number_of_methods, http_status, content_size
FROM df_final
WHERE (content_size != '0')
GROUP BY method, http_status, content_size
ORDER BY method, http_status, content_size
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>method</th><th>number_of_methods</th><th>http_status</th><th>content_size</th></tr></thead><tbody><tr><td>��6��T7�F��F</td><td>4</td><td>400</td><td>-</td></tr><tr><td>?</td><td>1</td><td>400</td><td>-</td></tr><tr><td>GET</td><td>78</td><td>200</td><td>-</td></tr><tr><td>GET</td><td>30</td><td>200</td><td>1000</td></tr><tr><td>GET</td><td>4</td><td>200</td><td>10000</td></tr><tr><td>GET</td><td>122</td><td>200</td><td>10002</td></tr><tr><td>GET</td><td>1</td><td>200</td><td>1001</td></tr><tr><td>GET</td><td>24</td><td>200</td><td>10015</td></tr><tr><td>GET</td><td>11</td><td>200</td><td>100203</td></tr><tr><td>GET</td><td>2</td><td>200</td><td>100223</td></tr><tr><td>GET</td><td>44</td><td>200</td><td>100268</td></tr><tr><td>GET</td><td>20</td><td>200</td><td>100269</td></tr><tr><td>GET</td><td>164</td><td>200</td><td>10032</td></tr><tr><td>GET</td><td>16</td><td>200</td><td>10036</td></tr><tr><td>GET</td><td>3</td><td>200</td><td>1004</td></tr><tr><td>GET</td><td>46</td><td>200</td><td>100481</td></tr><tr><td>GET</td><td>27</td><td>200</td><td>1005</td></tr><tr><td>GET</td><td>1</td><td>200</td><td>10053</td></tr><tr><td>GET</td><td>2</td><td>200</td><td>10054</td></tr><tr><td>GET</td><td>7</td><td>200</td><td>1006</td></tr><tr><td>GET</td><td>2</td><td>200</td><td>10063</td></tr><tr><td>GET</td><td>3</td><td>200</td><td>100665</td></tr><tr><td>GET</td><td>22</td><td>200</td><td>1007</td></tr><tr><td>GET</td><td>250</td><td>200</td><td>100705</td></tr><tr><td>GET</td><td>6</td><td>200</td><td>10075</td></tr><tr><td>GET</td><td>1</td><td>200</td><td>1007616</td></tr><tr><td>GET</td><td>2</td><td>200</td><td>10081</td></tr><tr><td>GET</td><td>16</td><td>200</td><td>100851</td></tr><tr><td>GET</td><td>4</td><td>200</td><td>1009</td></tr><tr><td>GET</td><td>603</td><td>200</td><td>10099</td></tr><tr><td>GET</td><td>1</td><td>200</td><td>101</td></tr><tr><td>GET</td><td>37</td><td>200</td><td>101087</td></tr><tr><td>GET</td><td>30</td><td>200</td><td>101095</td></tr><tr><td>GET</td><td>1</td><td>200</td><td>10113</td></tr><tr><td>GET</td><td>401</td><td>200</td><td>101267</td></tr><tr><td>GET</td><td>5</td><td>200</td><td>10133</td></tr><tr><td>GET</td><td>16</td><td>200</td><td>10135</td></tr><tr><td>GET</td><td>344</td><td>200</td><td>10136</td></tr><tr><td>GET</td><td>7</td><td>200</td><td>101360</td></tr><tr><td>GET</td><td>207</td><td>200</td><td>1013716</td></tr><tr><td>GET</td><td>32</td><td>200</td><td>10138</td></tr><tr><td>GET</td><td>1</td><td>200</td><td>10144</td></tr><tr><td>GET</td><td>1</td><td>200</td><td>101465</td></tr><tr><td>GET</td><td>1</td><td>200</td><td>10148</td></tr><tr><td>GET</td><td>1</td><td>200</td><td>10150</td></tr><tr><td>GET</td><td>21</td><td>200</td><td>101521</td></tr><tr><td>GET</td><td>10</td><td>200</td><td>101571</td></tr><tr><td>GET</td><td>1</td><td>200</td><td>1015808</td></tr><tr><td>GET</td><td>1762</td><td>200</td><td>1016</td></tr><tr><td>GET</td><td>69</td><td>200</td><td>101647</td></tr><tr><td>GET</td><td>1</td><td>200</td><td>10166</td></tr><tr><td>GET</td><td>164</td><td>200</td><td>101688</td></tr><tr><td>GET</td><td>56</td><td>200</td><td>101691</td></tr><tr><td>GET</td><td>18</td><td>200</td><td>1018</td></tr><tr><td>GET</td><td>1</td><td>200</td><td>10183</td></tr><tr><td>GET</td><td>41</td><td>200</td><td>101950</td></tr><tr><td>GET</td><td>26</td><td>200</td><td>102016</td></tr><tr><td>GET</td><td>5</td><td>200</td><td>10205</td></tr><tr><td>GET</td><td>5</td><td>200</td><td>102105</td></tr><tr><td>GET</td><td>1</td><td>200</td><td>1022</td></tr><tr><td>GET</td><td>2</td><td>200</td><td>102326</td></tr><tr><td>GET</td><td>97</td><td>200</td><td>102358</td></tr><tr><td>GET</td><td>17</td><td>200</td><td>102381</td></tr><tr><td>GET</td><td>1</td><td>200</td><td>10240</td></tr><tr><td>GET</td><td>2</td><td>200</td><td>1024000</td></tr><tr><td>GET</td><td> ...

# %% [markdown]
# # Extract the domain_name and count number of domain_names

# %%
# %sql
SELECT domain_name, COUNT(domain_name) as number_of_domain_name
FROM df_final
GROUP BY domain_name
ORDER BY number_of_domain_name
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>domain_name</th><th>number_of_domain_name</th></tr></thead><tbody><tr><td>.arpa</td><td>302</td></tr><tr><td>.my</td><td>550</td></tr><tr><td>.gb</td><td>636</td></tr><tr><td>.cz</td><td>661</td></tr><tr><td>.mx</td><td>921</td></tr><tr><td>.ve</td><td>1102</td></tr><tr><td>.ie</td><td>1239</td></tr><tr><td>.bm</td><td>1303</td></tr><tr><td>.lu</td><td>1537</td></tr><tr><td>.gr</td><td>1862</td></tr><tr><td>.pl</td><td>1914</td></tr><tr><td>.sk</td><td>1916</td></tr><tr><td>.sg</td><td>1937</td></tr><tr><td>.mt</td><td>2143</td></tr><tr><td>.kr</td><td>2219</td></tr><tr><td>.hu</td><td>2274</td></tr><tr><td>.nz</td><td>2422</td></tr><tr><td>.ni</td><td>2487</td></tr><tr><td>.il</td><td>2737</td></tr><tr><td>.za</td><td>2863</td